# %% [markdown]
# # Apple Leaf and Fruit Diseases Classification Using DenseNet 121

# %% [markdown]
# Dataset credits: https://github.com/hsaleem1/NZDLPlantDisease-v1

# %% [markdown]
# Mount Google Drive

# %%
#Mount google drive to google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path ="/content/drive/MyDrive/Classroom/NewNZdataset"

# %% [markdown]
# DenseNet Training from scratch is among the best two models. External_test dataset is used in prediction after evaluating the model with test dataset.

# %%
external_testing = "/content/drive/MyDrive/Classroom/External testing Dataset"

# %% [markdown]
# ### Import all the Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Flatten
from tensorflow.keras.models import Model

# %% [markdown]
# ### Set all the Constants

# %%
BATCH_SIZE =64
IMAGE_SIZE = 224  #---“input shape has to be `(224, 224, 3)” → DenseNet121
CHANNELS=3
epochs=100
classes =7

# %% [markdown]
# ### Import data into tensorflow dataset object

# %% [markdown]
# We will use image_dataset_from_directory api to load all images in tensorflow dataset: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 15706 files belonging to 7 classes.

# %% [markdown]
# Loading External testing dataset to Test the best model

# %%
external_test = tf.keras.preprocessing.image_dataset_from_directory(
    external_testing,
    seed=41,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 726 files belonging to 7 classes.

# %%
#Print class names
class_names = dataset.class_names

class_names
# Out:
# ['Black rot',
#  'Black spot',
#  'European Canker',
#  'Healthy Fruit',
#  'Healthy Leaf',
#  'Leaf spot (scab)',
#  'Mosaic virus ']

# %% [markdown]
# EXPLORATORY DATA ANALYSIS (EDA)

# %%
#Total number of images ≈ Number of batches × Batch size
len(dataset)
# Out:
# 246

# %%
# Count the number of images per class
class_counts = dict.fromkeys(class_names, 0)

for images, labels in dataset:
    for label in labels:
        label = int(label.numpy())  # Convert to int if necessary
        class_counts[class_names[label]] += 1

# Plotting the class distribution
plt.figure(figsize=(8, 4))
plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Count the Element in Each Class

# %%
import tensorflow as tf
from collections import defaultdict

class_counts = defaultdict(int)

# Iterate through the dataset to count occurrences of each class
for batch in dataset:
    # Extract labels from the batch
    labels = batch[1]

    # Count occurrences of each label in this batch
    for label in labels:
        class_counts[label.numpy()] += 1

# Display the counts for each class with class names
print("Class counts:")
for class_index, count in class_counts.items():
    class_name = class_names[class_index]
    print(f"{class_name}: {count} images")
# Out:
# Class counts:
# Leaf spot (scab): 3368 images
# European Canker: 2147 images
# Healthy Leaf: 2765 images
# Healthy Fruit: 2282 images
# Mosaic virus : 2636 images
# Black rot: 742 images
# Black spot: 1766 images

# %% [markdown]
# # Defining Class Weights
#
# There are many more observations of the Leaf spot class, and so this will have a larger impact on the overall value of the loss function than observations belonging to the other classes. the weight is going to be used for training the models

# %%
# Example class counts (use your actual counts)
class_counts = {
    "Healthy Leaf": 2765,
    "Healthy Fruit": 2282,
    "Black spot": 1766,
    "European Canker": 2147,
    "Mosaic virus": 2636,
    "Leaf spot (scab)": 3368,
    "Black rot": 742,
}

# Total number of samples and unique classes
total_samples = sum(class_counts.values())
num_classes = len(class_counts)

# Calculate class weights
class_weights = {}
for i, (class_name, count) in enumerate(class_counts.items()):
    weight = total_samples / (num_classes * count)
    class_weights[i] = weight

# %%
#Check the shape of the first batch
for image_batch, labels_batch in dataset.take(1):
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
for image_batch in dataset.take(1):
    print(image_batch[0].numpy())
# Out:
# [[[[1.69005112e+02 2.06719391e+02 6.97091904e+01]
#    [1.58362228e+02 1.89790802e+02 8.76887665e+01]
#    [8.69948959e+01 1.07234688e+02 5.43265305e+01]
#    ...
#    [2.49147964e+02 2.52122452e+02 1.97510239e+02]
#    [2.51933701e+02 2.54147980e+02 2.05688828e+02]
#    [2.54438812e+02 2.54714279e+02 2.14602173e+02]]
#
#   [[1.51438782e+02 1.88954086e+02 5.46785736e+01]
#    [1.63571426e+02 1.95045914e+02 9.24387741e+01]
#    [1.18632652e+02 1.39418365e+02 8.27806091e+01]
#    ...
#    [2.51698959e+02 2.53989777e+02 1.96193863e+02]
#    [2.50408157e+02 2.52193863e+02 2.00331665e+02]
#    [2.50285721e+02 2.51857147e+02 2.04423523e+02]]
#
#   [[1.41260208e+02 1.77714294e+02 4.91326523e+01]
#    [1.60341843e+02 1.92061218e+02 8.86020432e+01]
#    [1.27357132e+02 1.49285721e+02 8.58163223e+01]
#    ...
#    [2.49178543e+02 2.50306091e+02 1.89464279e+02]
#    [2.49352051e+02 2.49846939e+02 1.92933701e+02]
#    [2.52295975e+02 2.52653107e+02 2.00760330e+02]]
#
#   ...
#
#   [[7.85714035e+01 1.05571404e+02 5.45714073e+01]
#    [7.71428375e+01 1.04142838e+02 5.31428375e+01]
#    [7.91734543e+01 1.06173454e+02 5.51734543e+01]
#    ...
#    [2.40061142e+02 2.55000000e+02 1.56877457e+02]
#    [2.30795715e+02 2.48096802e+02 1.51515106e+02]
#    [1.94156723e+02 2.11656799e+02 1.16534241e+02]]
#
#   [[7.56683502e+01 1.02668350e+02 5.16683502e+01]
#    [7.64285736e+01 1.03428574e+02 5.24285736e+01]
#    [7.78724442e+01 1.04872444e+02 5.38724403e+01]
#    ...
#    [2.19162704e+02 2.39341446e+02 1.35106613e+02]
#    [1.54611221e+02 1.79851074e+02 7.40908279e+01]
#    [1.38244598e+02 1.63744659e+02 5.84588852e+01]]
#
#   [[7.25509720e+01 9.95509720e+01 4.85509720e+01]
#    [7.73571625e+01 1.04357162e+02 5.33571625e+01]
#    [7.72448883e+01 1.04244888e+02 5.32448921e+01]
#    ...
#    [1.54947372e+02 1.80814865e+02 7.00136871e+01]
#    [1.25326233e+02 1.53969131e+02 4.35558319e+01]
#    [1.25163239e+02 1.56607254e+02 4.59592056e+01]]]
#
#
#  [[[2.20612240e+01 6.10612259e+01 4.06122446e+00]
#    [2.44846935e+01 6.34846916e+01 6.48469353e+00]
#    [2.22908154e+01 6.12908134e+01 4.29081583e+00]
#    ...
#    [1.29688660e+02 1.26688660e+02 1.09688660e+02]
#    [1.34428650e+02 1.31428650e+02 1.14428642e+02]
#    [1.35923447e+02 1.32923447e+02 1.15923454e+02]]
#
#   [[2.09438782e+01 5.97295952e+01 2.72959232e+00]
#    [2.16428566e+01 6.04744873e+01 3.47449017e+00]
#    [1.98673477e+01 5.88673477e+01 1.86734772e+00]
#    ...
#    [1.25499893e+02 1.22928459e+02 1.05285606e+02]
#    [1.30403137e+02 1.27831703e+02 1.10525581e+02]
#    [1.33112259e+02 1.30540817e+02 1.13326538e+02]]
#
#   [[2.30459175e+01 6.10459175e+01 4.04591799e+00]
#    [2.42193871e+01 6.24336739e+01 5.43367290e+00]
#    [2.29030609e+01 6.19030609e+01 4.90306091e+00]
#    ...
#    [1.21214180e+02 1.20214180e+02 1.00214180e+02]
#    [1.24658218e+02 1.23658218e+02 1.05229660e+02]
#    [1.28760239e+02 1.27760246e+02 1.09760246e+02]]
#
#   ...
#
#   [[7.69030457e+01 1.30903030e+02 4.69030418e+01]
#    [7.91428452e+01 1.33142853e+02 4.91428452e+01]
#    [7.94030609e+01 1.33403061e+02 4.94030647e+01]
#    ...
#    [7.40000000e+01 1.33000000e+02 3.90000000e+01]
#    [7.27806244e+01 1.33352066e+02 4.01377831e+01]
#    [7.45000458e+01 1.35500046e+02 4.25000458e+01]]
#
#   [[7.59897995e+01 1.29989792e+02 4.59897919e+01]
#    [7.61479416e+01 1.30147934e+02 4.61479378e+01]
#    [7.75203934e+01 1.31520386e+02 4.75203934e+01]
#    ...
#    [7.49948730e+01 1.33994873e+02 4.10051003e+01]
#    [7.25969238e+01 1.33168365e+02 4.02908134e+01]
#    [7.33418427e+01 1.34341843e+02 4.13418465e+01]]
#
#   [[7.74541092e+01 1.31454102e+02 4.74541130e+01]
#    [7.30407791e+01 1.27040779e+02 4.30407715e+01]
#    [7.40815735e+01 1.28081573e+02 4.40815773e+01]
#    ...
#    [7.56683578e+01 1.34668350e+02 4.26173477e+01]
#    [7.26275330e+01 1.33198975e+02 4.04132576e+01]
#    [7.20663147e+01 1.33066315e+02 4.00663109e+01]]]
#
#
#  [[[9.99540863e+01 1.46091827e+02 5.25255089e+01]
#    [1.31785736e+02 1.65959198e+02 7.48112411e+01]
#    [2.30591827e+02 2.42331635e+02 1.58520401e+02]
#    ...
#    [2.06291656e+02 1.89628403e+02 1.66909012e+02]
#    [2.48979721e+02 2.36852203e+02 2.17724686e+02]
#    [1.70564774e+02 1.61284195e+02 1.44141357e+02]]
#
#   [[7.45510178e+01 1.15209175e+02 3.00255051e+01]
#    [1.26561241e+02 1.54989807e+02 6.98418503e+01]
#    [2.06994904e+02 2.15163254e+02 1.33418365e+02]
#    ...
#    [2.10944626e+02 1.95679321e+02 1.71260971e+02]
#    [2.47928680e+02 2.34658279e+02 2.14280762e+02]
#    [2.10233917e+02 1.98320663e+02 1.80019669e+02]]
#
#   [[7.62857208e+01 1.09158173e+02 3.60663338e+01]
#    [1.37954102e+02 1.58357147e+02 8.21275635e+01]
#    [1.77306122e+02 1.81249985e+02 1.07239777e+02]
#    ...
#    [2.22856598e+02 2.11177948e+02 1.83081024e+02]
#    [2.35699234e+02 2.20913513e+02 1.97913559e+02]
#    [1.94458252e+02 1.78131699e+02 1.59601135e+02]]
#
#   ...
#
#   [[4.05964699e+01 4.95964699e+01 3.25964699e+01]
#    [4.98113327e+01 5.88113327e+01 4.18113327e+01]
#    [4.74287033e+01 5.64287033e+01 3.94287033e+01]
#    ...
#    [1.44488735e+01 2.61631374e+01 9.44887352e+00]
#    [4.77039146e+00 1.34132290e+01 1.11732459e+00]
#    [1.04492569e+01 1.65920792e+01 4.77568102e+00]]
#
#   [[3.76735725e+01 4.58878517e+01 3.06837864e+01]
#    [1.98517647e+01 2.80660439e+01 1.51068954e+01]
#    [3.89182587e+01 4.71325378e+01 3.17039795e+01]
#    ...
#    [1.50458956e+01 2.67601604e+01 9.54078102e+00]
#    [7.45403862e+00 1.67142334e+01 1.83668149e+00]
#    [9.41839218e+00 1.78061581e+01 1.59181786e+00]]
#
#   [[1.03616676e+01 1.83616676e+01 3.38207054e+00]
#    [9.18874741e+00 1.71887493e+01 2.41318274e+00]
#    [1.29434547e+01 2.09434547e+01 5.94345474e+00]
#    ...
#    [2.03062019e+01 3.20204659e+01 1.46633339e+01]
#    [2.13267975e+01 3.07553558e+01 1.38675728e+01]
#    [1.41581383e+01 2.31581383e+01 6.16833735e+00]]]
#
#
#  ...
#
#
#  [[[4.33775520e+01 9.43826523e+01 1.78418350e+01]
#    [3.60918350e+01 8.71632614e+01 8.15816307e+00]
#    [3.82959175e+01 8.96989822e+01 9.08673477e+00]
#    ...
#    [4.60558472e+01 8.67037506e+01 4.05599880e+00]
#    [5.11429749e+01 8.45970154e+01 1.68368757e+00]
#    [9.10159836e+01 1.20230217e+02 3.63016624e+01]]
#
#   [[2.11020432e+01 7.19438782e+01 0.00000000e+00]
#    [2.78673477e+01 7.94387741e+01 0.00000000e+00]
#    [3.09387760e+01 8.25102005e+01 0.00000000e+00]
#    ...
#    [5.20560875e+01 9.05457993e+01 1.83671188e+00]
#    [5.41122704e+01 8.62500000e+01 4.04594374e+00]
#    [9.85110168e+01 1.27067093e+02 4.67099686e+01]]
#
#   [[4.29183693e+01 9.29438782e+01 7.29591990e+00]
#    [3.29030609e+01 8.32602081e+01 0.00000000e+00]
#    [3.16836758e+01 8.20408173e+01 0.00000000e+00]
#    ...
#    [5.22142181e+01 8.87702713e+01 4.13262510e+00]
#    [5.50663681e+01 8.38520355e+01 8.65820885e+00]
#    [8.86638718e+01 1.13760765e+02 4.17812042e+01]]
#
#   ...
#
#   [[8.75051270e+01 1.52505127e+02 2.25051231e+01]
#    [1.13525482e+02 1.78525482e+02 4.89540558e+01]
#    [9.12040253e+01 1.56204025e+02 2.89183159e+01]
#    ...
#    [7.23929367e+01 8.33929367e+01 4.93929329e+01]
#    [8.82702866e+01 9.92702866e+01 6.52702866e+01]
#    [7.79641953e+01 8.89641953e+01 5.49641953e+01]]
#
#   [[8.97143021e+01 1.56285736e+02 2.55000191e+01]
#    [1.04816254e+02 1.71050964e+02 4.08621826e+01]
#    [8.54744492e+01 1.50193848e+02 2.37499695e+01]
#    ...
#    [7.46173096e+01 8.56173096e+01 5.16173096e+01]
#    [6.28314018e+01 7.38314056e+01 3.98314018e+01]
#    [9.03118439e+01 1.01311844e+02 6.73118439e+01]]
#
#   [[9.29949493e+01 1.59994949e+02 2.89949512e+01]
#    [9.60764084e+01 1.62647827e+02 3.26886597e+01]
#    [8.43571396e+01 1.49000000e+02 2.39796124e+01]
#    ...
#    [7.26631470e+01 8.36631470e+01 4.96631508e+01]
#    [4.79894218e+01 5.89894218e+01 2.49894218e+01]
#    [9.12100906e+01 1.02210091e+02 6.82100906e+01]]]
#
#
#  [[[1.73724503e+02 1.57724503e+02 1.32653061e+02]
#    [1.74530609e+02 1.58316315e+02 1.33045914e+02]
#    [1.51188766e+02 1.33117340e+02 1.06760201e+02]
#    ...
#    [2.34229492e+02 2.47326447e+02 1.67515213e+02]
#    [1.32198151e+02 1.45514481e+02 6.54838715e+01]
#    [2.26594116e+02 2.40012482e+02 1.59879822e+02]]
#
#   [[1.60806122e+02 1.44591827e+02 1.18132645e+02]
#    [1.27469391e+02 1.10994904e+02 8.41377563e+01]
#    [8.20612411e+01 6.37908363e+01 3.65000153e+01]
#    ...
#    [2.14148132e+02 2.35214462e+02 1.52785889e+02]
#    [1.78086395e+02 1.95805756e+02 1.16969055e+02]
#    [1.71887848e+02 1.92719559e+02 1.10617439e+02]]
#
#   [[1.56306122e+02 1.38591843e+02 1.09071434e+02]
#    [2.06831619e+02 1.88841843e+02 1.58051025e+02]
#    [1.93561218e+02 1.74561218e+02 1.43030609e+02]
#    ...
#    [2.07673401e+02 2.39275452e+02 1.55045868e+02]
#    [2.22265442e+02 2.47913345e+02 1.71188919e+02]
#    [1.58937500e+02 1.90554993e+02 1.06891563e+02]]
#
#   ...
#
#   [[1.25407219e+01 3.65407219e+01 3.73461962e+00]
#    [2.72246056e+01 5.16531792e+01 1.70103207e+01]
#    [2.96022663e+01 5.58573608e+01 1.92400017e+01]
#    ...
#    [9.05971680e+01 1.30597168e+02 9.35971680e+01]
#    [9.01837769e+01 1.30183777e+02 9.31837769e+01]
#    [9.03059769e+01 1.30305984e+02 9.33059769e+01]]
#
#   [[1.58827066e+01 3.98827057e+01 6.28065443e+00]
#    [2.69030266e+01 5.13316002e+01 1.66887417e+01]
#    [2.22396736e+01 4.82396698e+01 1.26427460e+01]
#    ...
#    [8.59440002e+01 1.25944000e+02 8.89440002e+01]
#    [8.03926392e+01 1.20392639e+02 8.33926392e+01]
#    [9.44646912e+01 1.34464691e+02 9.74646912e+01]]
#
#   [[1.81734791e+01 4.21734810e+01 8.17347908e+00]
#    [2.07448044e+01 4.51733742e+01 1.05305176e+01]
#    [1.56938305e+01 4.16938286e+01 4.82134962e+00]
#    ...
#    [8.82450256e+01 1.28245026e+02 9.12450256e+01]
#    [9.55973434e+01 1.35597351e+02 9.85973434e+01]
#    [1.01454247e+02 1.41454239e+02 1.04454247e+02]]]
#
#
#  [[[6.83520432e+01 1.42341843e+02 2.93571434e+01]
#    [6.23979568e+01 1.35214279e+02 2.32397957e+01]
#    [6.18877525e+01 1.30173477e+02 2.22704086e+01]
#    ...
#    [4.59191613e-02 3.64797878e+00 7.14285970e-02]
#    [2.20409942e+00 6.86736822e+00 2.93369722e+00]
#    [1.98931009e-01 4.25503969e+00 2.65241355e-01]]
#
#   [[6.46530609e+01 1.38112244e+02 2.59234676e+01]
#    [5.67346916e+01 1.28091827e+02 1.84438744e+01]
#    [5.68112221e+01 1.24943871e+02 1.81683655e+01]
#    ...
#    [5.05110502e-01 8.02038765e+00 7.85714149e-01]
#    [5.05105877e+00 9.37757111e+00 5.38779688e+00]
#    [6.01530600e+00 1.11888037e+01 6.24489450e+00]]
#
#   [[5.39081612e+01 1.24836731e+02 1.52704067e+01]
#    [4.40714264e+01 1.14433670e+02 6.64285707e+00]
#    [4.70408173e+01 1.14025513e+02 1.13673468e+01]
#    ...
#    [0.00000000e+00 6.37751961e+00 0.00000000e+00]
#    [1.49286938e+01 2.47756710e+01 1.67807503e+01]
#    [2.83522167e+01 3.97552834e+01 2.94491310e+01]]
#
#   ...
#
#   [[2.09760162e+02 2.51193878e+02 1.97596924e+02]
#    [2.15510178e+02 2.53989777e+02 2.01938751e+02]
#    [2.22571381e+02 2.55000000e+02 2.08571381e+02]
#    ...
#    [1.59586716e+02 2.52989746e+02 6.00867958e+01]
#    [1.63642868e+02 2.53362228e+02 7.16531601e+01]
#    [1.62724487e+02 2.51127533e+02 7.54133606e+01]]
#
#   [[2.06729584e+02 2.52714294e+02 1.97943878e+02]
#    [2.11928558e+02 2.54663269e+02 2.00903061e+02]
#    [2.17867325e+02 2.55000000e+02 2.05515289e+02]
#    ...
#    [1.59280609e+02 2.53943878e+02 6.25154037e+01]
#    [1.62311249e+02 2.53076538e+02 7.41225433e+01]
#    [1.64673508e+02 2.54260239e+02 8.08164291e+01]]
#
#   [[2.07081650e+02 2.54867386e+02 1.99933701e+02]
#    [2.10158142e+02 2.55000000e+02 2.01586746e+02]
#    [2.15545898e+02 2.55000000e+02 2.04408157e+02]
#    ...
#    [1.60882675e+02 2.54954086e+02 6.56633759e+01]
#    [1.62540833e+02 2.53413254e+02 7.57704926e+01]
#    [1.63994904e+02 2.53132629e+02 8.25715332e+01]]]]

# %% [markdown]
# As you can see above, each element in the dataset is a tuple. First element is a batch of 64 elements of images. Second element is a batch of 64 elements of class labels

# %% [markdown]
# ### Visualize some of the images from our dataset

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ### Function to Split Dataset
#
# Dataset should be bifurcated into 3 subsets, namely:
# 1. Training: Dataset to be used while training
# 2. Validation: Dataset to be tested against while training
# 3. Test: Dataset to be tested against after we trained a model

# %%
def get_dataset_partitions_tf(ds, train_split=0.7, val_split=0.2, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 172

# %%
len(val_ds)
# Out:
# 49

# %%
len(test_ds)
# Out:
# 25

# %% [markdown]
# ### Cache, Shuffle, and Prefetch the Dataset

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
external_test = external_test.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### Creating a Layer for Normalization
# Creating a Layer for Normalization
# Before we feed our images to network,  to improve model performance, we should normalize the image pixel value (keeping them in range 0 and 1 by dividing by 256).
# This should happen while training as well as inference. Hence we can add that as a layer in our Sequential Model.

# %%
#normalization
rescale = tf.keras.Sequential([
layers.experimental.preprocessing.Rescaling(1./255),
])

# %% [markdown]
# ## Building the Model

# %% [markdown]
# ### Model Architecture
# We use a CNN coupled with a Softmax activation in the output layer. We also add the initial layers for resizing, normalization and Data Augmentation.

# %% [markdown]
# # Training from Scratch

# %%
from tensorflow.keras.layers import Input , BatchNormalization , ReLU , Conv2D , Dense , MaxPool2D , AvgPool2D , GlobalAvgPool2D , Concatenate
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.utils import plot_model

# %%
 def bat_relu_conv(x , filters , kernel_size) :
  x = BatchNormalization()(x)
  x = ReLU()(x)
  x = Conv2D(filters=filters , kernel_size=kernel_size , padding="same")(x)
  return x

# %%
def Dense_block(tensor , k , reps):
  for _ in range(reps):
    x = bat_relu_conv(tensor , filters=4*k , kernel_size=1)
    x = bat_relu_conv(x , filters=k , kernel_size=3)
    tensor = Concatenate()([tensor , x])
  return tensor

# %%
def transition_layer(x , theta=0.5):
  #  (0 < theta <= 1) if a dense block contains M feature-maps ,
  #  we let the following transition layer generate (thete of M) output feature-maps
  f = int(tf.keras.backend.int_shape(x)[-1] * theta)
  x = bat_relu_conv(x , filters=f , kernel_size=1)
  x = AvgPool2D(2 , strides=2 , padding="same")(x)
  return x

# %%
k = 32
REPETITIONS = 6,12,24,16
INPUT_SHAPE = (224,224,3)
input = Input(shape=INPUT_SHAPE)

# Input layer with normalization
input = Input(shape=INPUT_SHAPE)
input = rescale(input)  # Apply normalization

# the top of our model
x = Conv2D(filters=2*k , kernel_size=7 , strides=2 , padding="same")(input)
x = MaxPool2D(pool_size=3 , strides=2 , padding="same")(x)
# the main model


for reps in REPETITIONS:
  d = Dense_block(x ,k=k,  reps=reps)
  x = transition_layer(d , theta=0.5)


# the tail model
x = GlobalAvgPool2D()(d) # apply the GlobalAvgPool2D to the output of the dense layer
output = Dense(classes, activation="softmax")(x)


model = Model(input , output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input_3[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['conv2d[1][0]']
#  D)
#
#  batch_normalization (Batch  (None, 56, 56, 64)           256       ['max_pooling2d[1][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 56, 56, 64)           0         ['batch_normalization[1][0]']
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 128)          8320      ['re_lu[1][0]']
#
#  batch_normalization_1 (Bat  (None, 56, 56, 128)          512       ['conv2d_1[1][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_1[1][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_1[1][0]']
#
#  concatenate (Concatenate)   (None, 56, 56, 96)           0         ['max_pooling2d[1][0]',
#                                                                      'conv2d_2[1][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 96)           384       ['concatenate[1][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 56, 56, 96)           0         ['batch_normalization_2[1][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 128)          12416     ['re_lu_2[1][0]']
#
#  batch_normalization_3 (Bat  (None, 56, 56, 128)          512       ['conv2d_3[1][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_3[1][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_3[1][0]']
#
#  concatenate_1 (Concatenate  (None, 56, 56, 128)          0         ['concatenate[1][0]',
#  )                                                                   'conv2d_4[1][0]']
#
#  batch_normalization_4 (Bat  (None, 56, 56, 128)          512       ['concatenate_1[1][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_4[1][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)          16512     ['re_lu_4[1][0]']
#
#  batch_normalization_5 (Bat  (None, 56, 56, 128)          512       ['conv2d_5[1][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_5[1][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_5[1][0]']
#
#  concatenate_2 (Concatenate  (None, 56, 56, 160)          0         ['concatenate_1[1][0]',
#  )                                                                   'conv2d_6[1][0]']
#
#  batch_normalization_6 (Bat  (None, 56, 56, 160)          640       ['concatenate_2[1][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 56, 56, 160)          0         ['batch_normalization_6[1][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 128)          20608     ['re_lu_6[1][0]']
#
#  batch_normalization_7 (Bat  (None, 56, 56, 128)          512       ['conv2d_7[1][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_7[1][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_7[1][0]']
#
#  concatenate_3 (Concatenate  (None, 56, 56, 192)          0         ['concatenate_2[1][0]',
#  )                                                                   'conv2d_8[1][0]']
#
#  batch_normalization_8 (Bat  (None, 56, 56, 192)          768       ['concatenate_3[1][0]']
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 56, 56, 192)          0         ['batch_normalization_8[1][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 128)          24704     ['re_lu_8[1][0]']
#
#  batch_normalization_9 (Bat  (None, 56, 56, 128)          512       ['conv2d_9[1][0]']
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_9[1][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 32)           36896     ['re_lu_9[1][0]']
#
#  concatenate_4 (Concatenate  (None, 56, 56, 224)          0         ['concatenate_3[1][0]',
#  )                                                                   'conv2d_10[1][0]']
#
#  batch_normalization_10 (Ba  (None, 56, 56, 224)          896       ['concatenate_4[1][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 56, 56, 224)          0         ['batch_normalization_10[1][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 56, 56, 128)          28800     ['re_lu_10[1][0]']
#
#  batch_normalization_11 (Ba  (None, 56, 56, 128)          512       ['conv2d_11[1][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 56, 56, 128)          0         ['batch_normalization_11[1][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 56, 56, 32)           36896     ['re_lu_11[1][0]']
#
#  concatenate_5 (Concatenate  (None, 56, 56, 256)          0         ['concatenate_4[1][0]',
#  )                                                                   'conv2d_12[1][0]']
#
#  batch_normalization_12 (Ba  (None, 56, 56, 256)          1024      ['concatenate_5[1][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 56, 56, 256)          0         ['batch_normalization_12[1][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 56, 56, 128)          32896     ['re_lu_12[1][0]']
#
#  average_pooling2d (Average  (None, 28, 28, 128)          0         ['conv2d_13[1][0]']
#  Pooling2D)
#
#  batch_normalization_13 (Ba  (None, 28, 28, 128)          512       ['average_pooling2d[1][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_13[1][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 128)          16512     ['re_lu_13[1][0]']
#
#  batch_normalization_14 (Ba  (None, 28, 28, 128)          512       ['conv2d_14[1][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_14[1][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_14[1][0]']
#
#  concatenate_6 (Concatenate  (None, 28, 28, 160)          0         ['average_pooling2d[1][0]',
#  )                                                                   'conv2d_15[1][0]']
#
#  batch_normalization_15 (Ba  (None, 28, 28, 160)          640       ['concatenate_6[1][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 28, 28, 160)          0         ['batch_normalization_15[1][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 128)          20608     ['re_lu_15[1][0]']
#
#  batch_normalization_16 (Ba  (None, 28, 28, 128)          512       ['conv2d_16[1][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_16[1][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_16[1][0]']
#
#  concatenate_7 (Concatenate  (None, 28, 28, 192)          0         ['concatenate_6[1][0]',
#  )                                                                   'conv2d_17[1][0]']
#
#  batch_normalization_17 (Ba  (None, 28, 28, 192)          768       ['concatenate_7[1][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 28, 28, 192)          0         ['batch_normalization_17[1][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 128)          24704     ['re_lu_17[1][0]']
#
#  batch_normalization_18 (Ba  (None, 28, 28, 128)          512       ['conv2d_18[1][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_18[1][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_18[1][0]']
#
#  concatenate_8 (Concatenate  (None, 28, 28, 224)          0         ['concatenate_7[1][0]',
#  )                                                                   'conv2d_19[1][0]']
#
#  batch_normalization_19 (Ba  (None, 28, 28, 224)          896       ['concatenate_8[1][0]']
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 28, 28, 224)          0         ['batch_normalization_19[1][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 128)          28800     ['re_lu_19[1][0]']
#
#  batch_normalization_20 (Ba  (None, 28, 28, 128)          512       ['conv2d_20[1][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_20[1][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_20[1][0]']
#
#  concatenate_9 (Concatenate  (None, 28, 28, 256)          0         ['concatenate_8[1][0]',
#  )                                                                   'conv2d_21[1][0]']
#
#  batch_normalization_21 (Ba  (None, 28, 28, 256)          1024      ['concatenate_9[1][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 28, 28, 256)          0         ['batch_normalization_21[1][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 128)          32896     ['re_lu_21[1][0]']
#
#  batch_normalization_22 (Ba  (None, 28, 28, 128)          512       ['conv2d_22[1][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_22[1][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_22[1][0]']
#
#  concatenate_10 (Concatenat  (None, 28, 28, 288)          0         ['concatenate_9[1][0]',
#  e)                                                                  'conv2d_23[1][0]']
#
#  batch_normalization_23 (Ba  (None, 28, 28, 288)          1152      ['concatenate_10[1][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 28, 28, 288)          0         ['batch_normalization_23[1][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 128)          36992     ['re_lu_23[1][0]']
#
#  batch_normalization_24 (Ba  (None, 28, 28, 128)          512       ['conv2d_24[1][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_24[1][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_24[1][0]']
#
#  concatenate_11 (Concatenat  (None, 28, 28, 320)          0         ['concatenate_10[1][0]',
#  e)                                                                  'conv2d_25[1][0]']
#
#  batch_normalization_25 (Ba  (None, 28, 28, 320)          1280      ['concatenate_11[1][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 28, 28, 320)          0         ['batch_normalization_25[1][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 128)          41088     ['re_lu_25[1][0]']
#
#  batch_normalization_26 (Ba  (None, 28, 28, 128)          512       ['conv2d_26[1][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_26[1][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_26[1][0]']
#
#  concatenate_12 (Concatenat  (None, 28, 28, 352)          0         ['concatenate_11[1][0]',
#  e)                                                                  'conv2d_27[1][0]']
#
#  batch_normalization_27 (Ba  (None, 28, 28, 352)          1408      ['concatenate_12[1][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 28, 28, 352)          0         ['batch_normalization_27[1][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 128)          45184     ['re_lu_27[1][0]']
#
#  batch_normalization_28 (Ba  (None, 28, 28, 128)          512       ['conv2d_28[1][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_28[1][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_28[1][0]']
#
#  concatenate_13 (Concatenat  (None, 28, 28, 384)          0         ['concatenate_12[1][0]',
#  e)                                                                  'conv2d_29[1][0]']
#
#  batch_normalization_29 (Ba  (None, 28, 28, 384)          1536      ['concatenate_13[1][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 28, 28, 384)          0         ['batch_normalization_29[1][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 128)          49280     ['re_lu_29[1][0]']
#
#  batch_normalization_30 (Ba  (None, 28, 28, 128)          512       ['conv2d_30[1][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_30[1][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_30[1][0]']
#
#  concatenate_14 (Concatenat  (None, 28, 28, 416)          0         ['concatenate_13[1][0]',
#  e)                                                                  'conv2d_31[1][0]']
#
#  batch_normalization_31 (Ba  (None, 28, 28, 416)          1664      ['concatenate_14[1][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 28, 28, 416)          0         ['batch_normalization_31[1][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 128)          53376     ['re_lu_31[1][0]']
#
#  batch_normalization_32 (Ba  (None, 28, 28, 128)          512       ['conv2d_32[1][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_32[1][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_32[1][0]']
#
#  concatenate_15 (Concatenat  (None, 28, 28, 448)          0         ['concatenate_14[1][0]',
#  e)                                                                  'conv2d_33[1][0]']
#
#  batch_normalization_33 (Ba  (None, 28, 28, 448)          1792      ['concatenate_15[1][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 28, 28, 448)          0         ['batch_normalization_33[1][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 128)          57472     ['re_lu_33[1][0]']
#
#  batch_normalization_34 (Ba  (None, 28, 28, 128)          512       ['conv2d_34[1][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_34[1][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_34[1][0]']
#
#  concatenate_16 (Concatenat  (None, 28, 28, 480)          0         ['concatenate_15[1][0]',
#  e)                                                                  'conv2d_35[1][0]']
#
#  batch_normalization_35 (Ba  (None, 28, 28, 480)          1920      ['concatenate_16[1][0]']
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 28, 28, 480)          0         ['batch_normalization_35[1][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 28, 28, 128)          61568     ['re_lu_35[1][0]']
#
#  batch_normalization_36 (Ba  (None, 28, 28, 128)          512       ['conv2d_36[1][0]']
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_36[1][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_36[1][0]']
#
#  concatenate_17 (Concatenat  (None, 28, 28, 512)          0         ['concatenate_16[1][0]',
#  e)                                                                  'conv2d_37[1][0]']
#
#  batch_normalization_37 (Ba  (None, 28, 28, 512)          2048      ['concatenate_17[1][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 28, 28, 512)          0         ['batch_normalization_37[1][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 256)          131328    ['re_lu_37[1][0]']
#
#  average_pooling2d_1 (Avera  (None, 14, 14, 256)          0         ['conv2d_38[1][0]']
#  gePooling2D)
#
#  batch_normalization_38 (Ba  (None, 14, 14, 256)          1024      ['average_pooling2d_1[1][0]']
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_38[1][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 128)          32896     ['re_lu_38[1][0]']
#
#  batch_normalization_39 (Ba  (None, 14, 14, 128)          512       ['conv2d_39[1][0]']
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_39[1][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_39[1][0]']
#
#  concatenate_18 (Concatenat  (None, 14, 14, 288)          0         ['average_pooling2d_1[1][0]',
#  e)                                                                  'conv2d_40[1][0]']
#
#  batch_normalization_40 (Ba  (None, 14, 14, 288)          1152      ['concatenate_18[1][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 14, 14, 288)          0         ['batch_normalization_40[1][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 128)          36992     ['re_lu_40[1][0]']
#
#  batch_normalization_41 (Ba  (None, 14, 14, 128)          512       ['conv2d_41[1][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_41[1][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_41[1][0]']
#
#  concatenate_19 (Concatenat  (None, 14, 14, 320)          0         ['concatenate_18[1][0]',
#  e)                                                                  'conv2d_42[1][0]']
#
#  batch_normalization_42 (Ba  (None, 14, 14, 320)          1280      ['concatenate_19[1][0]']
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 14, 14, 320)          0         ['batch_normalization_42[1][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 128)          41088     ['re_lu_42[1][0]']
#
#  batch_normalization_43 (Ba  (None, 14, 14, 128)          512       ['conv2d_43[1][0]']
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_43[1][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_43[1][0]']
#
#  concatenate_20 (Concatenat  (None, 14, 14, 352)          0         ['concatenate_19[1][0]',
#  e)                                                                  'conv2d_44[1][0]']
#
#  batch_normalization_44 (Ba  (None, 14, 14, 352)          1408      ['concatenate_20[1][0]']
#  tchNormalization)
#
#  re_lu_44 (ReLU)             (None, 14, 14, 352)          0         ['batch_normalization_44[1][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 14, 14, 128)          45184     ['re_lu_44[1][0]']
#
#  batch_normalization_45 (Ba  (None, 14, 14, 128)          512       ['conv2d_45[1][0]']
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_45[1][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_45[1][0]']
#
#  concatenate_21 (Concatenat  (None, 14, 14, 384)          0         ['concatenate_20[1][0]',
#  e)                                                                  'conv2d_46[1][0]']
#
#  batch_normalization_46 (Ba  (None, 14, 14, 384)          1536      ['concatenate_21[1][0]']
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 14, 14, 384)          0         ['batch_normalization_46[1][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 128)          49280     ['re_lu_46[1][0]']
#
#  batch_normalization_47 (Ba  (None, 14, 14, 128)          512       ['conv2d_47[1][0]']
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_47[1][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_47[1][0]']
#
#  concatenate_22 (Concatenat  (None, 14, 14, 416)          0         ['concatenate_21[1][0]',
#  e)                                                                  'conv2d_48[1][0]']
#
#  batch_normalization_48 (Ba  (None, 14, 14, 416)          1664      ['concatenate_22[1][0]']
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 14, 14, 416)          0         ['batch_normalization_48[1][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 14, 14, 128)          53376     ['re_lu_48[1][0]']
#
#  batch_normalization_49 (Ba  (None, 14, 14, 128)          512       ['conv2d_49[1][0]']
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_49[1][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_49[1][0]']
#
# ...
#  batch_normalization_103 (B  (None, 7, 7, 768)            3072      ['concatenate_49[1][0]']
#  atchNormalization)
#
#  re_lu_103 (ReLU)            (None, 7, 7, 768)            0         ['batch_normalization_103[1][0
#                                                                     ]']
#
#  conv2d_104 (Conv2D)         (None, 7, 7, 128)            98432     ['re_lu_103[1][0]']
#
#  batch_normalization_104 (B  (None, 7, 7, 128)            512       ['conv2d_104[1][0]']
#  atchNormalization)
#
#  re_lu_104 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_104[1][0
#                                                                     ]']
#
#  conv2d_105 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_104[1][0]']
#
#  concatenate_50 (Concatenat  (None, 7, 7, 800)            0         ['concatenate_49[1][0]',
#  e)                                                                  'conv2d_105[1][0]']
#
#  batch_normalization_105 (B  (None, 7, 7, 800)            3200      ['concatenate_50[1][0]']
#  atchNormalization)
#
#  re_lu_105 (ReLU)            (None, 7, 7, 800)            0         ['batch_normalization_105[1][0
#                                                                     ]']
#
#  conv2d_106 (Conv2D)         (None, 7, 7, 128)            102528    ['re_lu_105[1][0]']
#
#  batch_normalization_106 (B  (None, 7, 7, 128)            512       ['conv2d_106[1][0]']
#  atchNormalization)
#
#  re_lu_106 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_106[1][0
#                                                                     ]']
#
#  conv2d_107 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_106[1][0]']
#
#  concatenate_51 (Concatenat  (None, 7, 7, 832)            0         ['concatenate_50[1][0]',
#  e)                                                                  'conv2d_107[1][0]']
#
#  batch_normalization_107 (B  (None, 7, 7, 832)            3328      ['concatenate_51[1][0]']
#  atchNormalization)
#
#  re_lu_107 (ReLU)            (None, 7, 7, 832)            0         ['batch_normalization_107[1][0
#                                                                     ]']
#
#  conv2d_108 (Conv2D)         (None, 7, 7, 128)            106624    ['re_lu_107[1][0]']
#
#  batch_normalization_108 (B  (None, 7, 7, 128)            512       ['conv2d_108[1][0]']
#  atchNormalization)
#
#  re_lu_108 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_108[1][0
#                                                                     ]']
#
#  conv2d_109 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_108[1][0]']
#
#  concatenate_52 (Concatenat  (None, 7, 7, 864)            0         ['concatenate_51[1][0]',
#  e)                                                                  'conv2d_109[1][0]']
#
#  batch_normalization_109 (B  (None, 7, 7, 864)            3456      ['concatenate_52[1][0]']
#  atchNormalization)
#
#  re_lu_109 (ReLU)            (None, 7, 7, 864)            0         ['batch_normalization_109[1][0
#                                                                     ]']
#
#  conv2d_110 (Conv2D)         (None, 7, 7, 128)            110720    ['re_lu_109[1][0]']
#
#  batch_normalization_110 (B  (None, 7, 7, 128)            512       ['conv2d_110[1][0]']
#  atchNormalization)
#
#  re_lu_110 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_110[1][0
#                                                                     ]']
#
#  conv2d_111 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_110[1][0]']
#
#  concatenate_53 (Concatenat  (None, 7, 7, 896)            0         ['concatenate_52[1][0]',
#  e)                                                                  'conv2d_111[1][0]']
#
#  batch_normalization_111 (B  (None, 7, 7, 896)            3584      ['concatenate_53[1][0]']
#  atchNormalization)
#
#  re_lu_111 (ReLU)            (None, 7, 7, 896)            0         ['batch_normalization_111[1][0
#                                                                     ]']
#
#  conv2d_112 (Conv2D)         (None, 7, 7, 128)            114816    ['re_lu_111[1][0]']
#
#  batch_normalization_112 (B  (None, 7, 7, 128)            512       ['conv2d_112[1][0]']
#  atchNormalization)
#
#  re_lu_112 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_112[1][0
#                                                                     ]']
#
#  conv2d_113 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_112[1][0]']
#
#  concatenate_54 (Concatenat  (None, 7, 7, 928)            0         ['concatenate_53[1][0]',
#  e)                                                                  'conv2d_113[1][0]']
#
#  batch_normalization_113 (B  (None, 7, 7, 928)            3712      ['concatenate_54[1][0]']
#  atchNormalization)
#
#  re_lu_113 (ReLU)            (None, 7, 7, 928)            0         ['batch_normalization_113[1][0
#                                                                     ]']
#
#  conv2d_114 (Conv2D)         (None, 7, 7, 128)            118912    ['re_lu_113[1][0]']
#
#  batch_normalization_114 (B  (None, 7, 7, 128)            512       ['conv2d_114[1][0]']
#  atchNormalization)
#
#  re_lu_114 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_114[1][0
#                                                                     ]']
#
#  conv2d_115 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_114[1][0]']
#
#  concatenate_55 (Concatenat  (None, 7, 7, 960)            0         ['concatenate_54[1][0]',
#  e)                                                                  'conv2d_115[1][0]']
#
#  batch_normalization_115 (B  (None, 7, 7, 960)            3840      ['concatenate_55[1][0]']
#  atchNormalization)
#
#  re_lu_115 (ReLU)            (None, 7, 7, 960)            0         ['batch_normalization_115[1][0
#                                                                     ]']
#
#  conv2d_116 (Conv2D)         (None, 7, 7, 128)            123008    ['re_lu_115[1][0]']
#
#  batch_normalization_116 (B  (None, 7, 7, 128)            512       ['conv2d_116[1][0]']
#  atchNormalization)
#
#  re_lu_116 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_116[1][0
#                                                                     ]']
#
#  conv2d_117 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_116[1][0]']
#
#  concatenate_56 (Concatenat  (None, 7, 7, 992)            0         ['concatenate_55[1][0]',
#  e)                                                                  'conv2d_117[1][0]']
#
#  batch_normalization_117 (B  (None, 7, 7, 992)            3968      ['concatenate_56[1][0]']
#  atchNormalization)
#
#  re_lu_117 (ReLU)            (None, 7, 7, 992)            0         ['batch_normalization_117[1][0
#                                                                     ]']
#
#  conv2d_118 (Conv2D)         (None, 7, 7, 128)            127104    ['re_lu_117[1][0]']
#
#  batch_normalization_118 (B  (None, 7, 7, 128)            512       ['conv2d_118[1][0]']
#  atchNormalization)
#
#  re_lu_118 (ReLU)            (None, 7, 7, 128)            0         ['batch_normalization_118[1][0
#                                                                     ]']
#
#  conv2d_119 (Conv2D)         (None, 7, 7, 32)             36896     ['re_lu_118[1][0]']
#
#  concatenate_57 (Concatenat  (None, 7, 7, 1024)           0         ['concatenate_56[1][0]',
#  e)                                                                  'conv2d_119[1][0]']
#
#  global_average_pooling2d (  (None, 1024)                 0         ['concatenate_57[1][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 7)                    7175      ['global_average_pooling2d[1][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 7050567 (26.90 MB)
# Trainable params: 6969095 (26.58 MB)
# Non-trainable params: 81472 (318.25 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Defining Callbacks
#
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %%
import numpy as np
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Callback to reduce the learning rate when validation loss plateaus
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=np.sqrt(0.1),  # Factor to reduce learning rate
    patience=5,
    verbose=1
)

# Callback to stop training when validation loss doesn't improve
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,  # Number of epochs to wait before stopping
    verbose=1,
    restore_best_weights=True
)

# %% [markdown]
# Defining the Optimizer

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)

# %%
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=2,
    epochs=epochs,
    class_weight = class_weights,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/100
# 172/172 - 180s - loss: 1.3174 - accuracy: 0.5530 - val_loss: 2.3987 - val_accuracy: 0.4091 - lr: 0.0010 - 180s/epoch - 1s/step
# Epoch 2/100
# 172/172 - 42s - loss: 0.8639 - accuracy: 0.6695 - val_loss: 10.2285 - val_accuracy: 0.2643 - lr: 0.0010 - 42s/epoch - 246ms/step
# Epoch 3/100
# 172/172 - 42s - loss: 0.7282 - accuracy: 0.7103 - val_loss: 36.6519 - val_accuracy: 0.2325 - lr: 0.0010 - 42s/epoch - 245ms/step
# Epoch 4/100
# 172/172 - 42s - loss: 0.6257 - accuracy: 0.7464 - val_loss: 0.9330 - val_accuracy: 0.6722 - lr: 0.0010 - 42s/epoch - 247ms/step
# Epoch 5/100
# 172/172 - 42s - loss: 0.4912 - accuracy: 0.8096 - val_loss: 0.6011 - val_accuracy: 0.7631 - lr: 0.0010 - 42s/epoch - 247ms/step
# Epoch 6/100
# 172/172 - 42s - loss: 0.3981 - accuracy: 0.8507 - val_loss: 0.3603 - val_accuracy: 0.8594 - lr: 0.0010 - 42s/epoch - 247ms/step
# Epoch 7/100
# 172/172 - 42s - loss: 0.3393 - accuracy: 0.8791 - val_loss: 0.6785 - val_accuracy: 0.7886 - lr: 0.0010 - 42s/epoch - 245ms/step
# Epoch 8/100
# 172/172 - 42s - loss: 0.3135 - accuracy: 0.8906 - val_loss: 0.6610 - val_accuracy: 0.7612 - lr: 0.0010 - 42s/epoch - 246ms/step
# Epoch 9/100
# 172/172 - 42s - loss: 0.2525 - accuracy: 0.9095 - val_loss: 0.3831 - val_accuracy: 0.8705 - lr: 0.0010 - 42s/epoch - 246ms/step
# Epoch 10/100
# 172/172 - 42s - loss: 0.2304 - accuracy: 0.9194 - val_loss: 1.6876 - val_accuracy: 0.5883 - lr: 0.0010 - 42s/epoch - 245ms/step
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 172/172 - 42s - loss: 0.2495 - accuracy: 0.9167 - val_loss: 0.4454 - val_accuracy: 0.8533 - lr: 0.0010 - 42s/epoch - 245ms/step
# Epoch 12/100
# 172/172 - 42s - loss: 0.1036 - accuracy: 0.9641 - val_loss: 0.0911 - val_accuracy: 0.9630 - lr: 3.1623e-04 - 42s/epoch - 246ms/step
# Epoch 13/100
# 172/172 - 42s - loss: 0.0799 - accuracy: 0.9744 - val_loss: 0.1169 - val_accuracy: 0.9582 - lr: 3.1623e-04 - 42s/epoch - 245ms/step
# Epoch 14/100
# 172/172 - 42s - loss: 0.0670 - accuracy: 0.9794 - val_loss: 0.0704 - val_accuracy: 0.9742 - lr: 3.1623e-04 - 42s/epoch - 247ms/step
# Epoch 15/100
# 172/172 - 42s - loss: 0.0623 - accuracy: 0.9804 - val_loss: 0.2350 - val_accuracy: 0.9276 - lr: 3.1623e-04 - 42s/epoch - 246ms/step
# Epoch 16/100
# 172/172 - 42s - loss: 0.0579 - accuracy: 0.9817 - val_loss: 0.0626 - val_accuracy: 0.9754 - lr: 3.1623e-04 - 42s/epoch - 247ms/step
# Epoch 17/100
# 172/172 - 42s - loss: 0.0461 - accuracy: 0.9849 - val_loss: 0.0713 - val_accuracy: 0.9719 - lr: 3.1623e-04 - 42s/epoch - 246ms/step
# Epoch 18/100
# 172/172 - 42s - loss: 0.0457 - accuracy: 0.9854 - val_loss: 0.1004 - val_accuracy: 0.9713 - lr: 3.1623e-04 - 42s/epoch - 246ms/step
# Epoch 19/100
# 172/172 - 42s - loss: 0.0471 - accuracy: 0.9843 - val_loss: 0.4564 - val_accuracy: 0.8916 - lr: 3.1623e-04 - 42s/epoch - 246ms/step
# Epoch 20/100
# 172/172 - 42s - loss: 0.0474 - accuracy: 0.9843 - val_loss: 0.1376 - val_accuracy: 0.9525 - lr: 3.1623e-04 - 42s/epoch - 245ms/step
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 172/172 - 42s - loss: 0.0481 - accuracy: 0.9830 - val_loss: 0.1825 - val_accuracy: 0.9458 - lr: 3.1623e-04 - 42s/epoch - 246ms/step
# Epoch 22/100
# 172/172 - 42s - loss: 0.0307 - accuracy: 0.9886 - val_loss: 0.0448 - val_accuracy: 0.9809 - lr: 1.0000e-04 - 42s/epoch - 247ms/step
# Epoch 23/100
# 172/172 - 42s - loss: 0.0245 - accuracy: 0.9901 - val_loss: 0.0472 - val_accuracy: 0.9799 - lr: 1.0000e-04 - 42s/epoch - 246ms/step
# Epoch 24/100
# 172/172 - 42s - loss: 0.0226 - accuracy: 0.9916 - val_loss: 0.0817 - val_accuracy: 0.9723 - lr: 1.0000e-04 - 42s/epoch - 246ms/step
# Epoch 25/100
# 172/172 - 42s - loss: 0.0209 - accuracy: 0.9913 - val_loss: 0.0517 - val_accuracy: 0.9786 - lr: 1.0000e-04 - 42s/epoch - 246ms/step
# Epoch 26/100
# 172/172 - 42s - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.0559 - val_accuracy: 0.9783 - lr: 1.0000e-04 - 42s/epoch - 246ms/step
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 172/172 - 42s - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.0687 - val_accuracy: 0.9735 - lr: 1.0000e-04 - 42s/epoch - 246ms/step
# Epoch 28/100
# 172/172 - 42s - loss: 0.0144 - accuracy: 0.9949 - val_loss: 0.0528 - val_accuracy: 0.9780 - lr: 3.1623e-05 - 42s/epoch - 246ms/step
# Epoch 29/100
# 172/172 - 42s - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0536 - val_accuracy: 0.9786 - lr: 3.1623e-05 - 42s/epoch - 246ms/step
# Epoch 30/100
# 172/172 - 42s - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0569 - val_accuracy: 0.9786 - lr: 3.1623e-05 - 42s/epoch - 246ms/step
# Epoch 31/100
# 172/172 - 42s - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.0620 - val_accuracy: 0.9790 - lr: 3.1623e-05 - 42s/epoch - 246ms/step
# Epoch 32/100
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# Restoring model weights from the end of the best epoch: 22.
# 172/172 - 43s - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0600 - val_accuracy: 0.9802 - lr: 3.1623e-05 - 43s/epoch - 248ms/step
# Epoch 32: early stopping

# %% [markdown]
# Evaluate the test_ds

# %%
scores = model.evaluate(test_ds)
# Out:
# 25/25 [==============================] - 30s 143ms/step - loss: 0.0400 - accuracy: 0.9846

# %% [markdown]
# Evaluating the external test dataset

# %%
external_scores = model.evaluate(external_test)
# Out:
# 12/12 [==============================] - 40s 203ms/step - loss: 3.5800 - accuracy: 0.5592

# %% [markdown]
# Make prediction on a random image from test_ds

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Healthy Leaf
# 2/2 [==============================] - 0s 52ms/step
# predicted label: Healthy Leaf

# %% [markdown]
# Plotting training and validation accuracy, loss and learning rate

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np



# Get true and predicted labels
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model.predict(images)  # Get model predictions
    y_pred.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes

# Confusion Matrix with class names
cf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf_matrix, annot=True, cmap="Blues", fmt="g", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 [==============================] - 4s 24ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 2s 2s/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 37ms/step

# %% [markdown]
# Classification Report with Precision and Recall

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.96      1.00      0.98        66
#       Black spot       0.98      0.93      0.95       192
#  European Canker       1.00      1.00      1.00       210
#    Healthy Fruit       0.98      0.99      0.98       229
#     Healthy Leaf       1.00      0.98      0.99       271
# Leaf spot (scab)       1.00      1.00      1.00       311
#    Mosaic virus        0.96      0.99      0.97       283
#
#         accuracy                           0.98      1562
#        macro avg       0.98      0.98      0.98      1562
#     weighted avg       0.98      0.98      0.98      1562

# %% [markdown]
# ROC AUC

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true = []
y_pred_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model.predict(images)  # Get model predictions (probabilities)
    y_pred_probs.extend(predictions)  # Collect predicted probabilities

# Convert to NumPy arrays
y_true = np.array(y_true)  # Ensure true labels are arrays
y_pred_probs = np.array(y_pred_probs)  # Ensure predicted probabilities are arrays

# Binarize the true labels to get a one-hot encoded representation
y_true_bin = label_binarize(y_true, classes=list(range(20)))

# Initialize ROC and AUC data
fpr = dict()  # False positive rates
tpr = dict()  # True positive rates
roc_auc = dict()  # AUC for each class

# Compute ROC and AUC for each class
for i in range(classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])  # ROC data for each class
    roc_auc[i] = auc(fpr[i], tpr[i])  # AUC for each class

# Compute macro-average AUC
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(classes)]))
mean_tpr = np.zeros_like(all_fpr)

# Compute mean true positive rates
for i in range(classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= classes  # Normalize by the number of classes
macro_auc = auc(all_fpr, mean_tpr)  # Macro-average AUC

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')  # Label with class names and AUC

# Plot the macro-average ROC curve
plt.plot(all_fpr, mean_tpr, color='k', linestyle='--', label=f'Macro-average ROC (AUC = {macro_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 36ms/step

# %% [markdown]
# Classification Report on External Dataset

# %%
# Get true and predicted labels
y_true_external = []
y_pred_external = []

for images, labels in external_test:
    y_true_external.extend(labels.numpy())  # Collect true labels
    predictions = model.predict(images)  # Get model predictions
    y_pred_external.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes




report = classification_report(y_true_external, y_pred_external, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 37ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.28      0.36      0.31        42
#       Black spot       0.38      0.57      0.46       120
#  European Canker       0.50      0.99      0.66        72
#    Healthy Fruit       0.65      0.57      0.60        90
#     Healthy Leaf       0.48      0.23      0.31       126
# Leaf spot (scab)       0.35      0.17      0.23        54
#    Mosaic virus        0.89      0.73      0.80       222
#
#         accuracy                           0.56       726
#        macro avg       0.50      0.52      0.48       726
#     weighted avg       0.59      0.56      0.55       726

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in external_test.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Transfer Learning

# %%
from keras.applications import DenseNet121

# %%
from keras.layers import Input,Rescaling

# this could also be the output a different Keras model or layer
input = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
x = rescale(input)

# %%
# Load the dense pre-trained model without the top layer (fully connected layers)
dense =DenseNet121(input_tensor=x, weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
# Freeze the layers of dense
for layer in dense.layers:
  layer.trainable =False

# %%
x = GlobalAveragePooling2D()(dense.output)
prediction = Dense(classes, activation ='softmax')(x)
#create a model object
model_tl =Model(inputs =dense.input, outputs =prediction)
#View the structure of the model
model_tl.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  sequential (Sequential)     (None, 224, 224, 3)          0         ['input_5[0][0]']
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['sequential[2][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 112, 112, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 112, 112, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 56, 56, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 56, 56, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 56, 56, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 56, 56, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 56, 56, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 56, 56, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 56, 56, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 56, 56, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 56, 56, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 56, 56, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 56, 56, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 56, 56, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 56, 56, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 56, 56, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 56, 56, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 56, 56, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 56, 56, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 56, 56, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 56, 56, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 56, 56, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 56, 56, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 56, 56, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 56, 56, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 28, 28, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 28, 28, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 28, 28, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 28, 28, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 28, 28, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 28, 28, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 28, 28, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 28, 28, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 28, 28, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 28, 28, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 28, 28, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 28, 28, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 28, 28, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 28, 28, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 28, 28, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 28, 28, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 28, 28, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 28, 28, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 28, 28, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 28, 28, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 28, 28, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 28, 28, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 28, 28, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 28, 28, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 28, 28, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 28, 28, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 28, 28, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 28, 28, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 28, 28, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 28, 28, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 28, 28, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 28, 28, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 28, 28, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 28, 28, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 28, 28, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 28, 28, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 28, 28, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 28, 28, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 28, 28, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 28, 28, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 28, 28, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 28, 28, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 28, 28, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 28, 28, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 28, 28, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 28, 28, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 28, 28, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 28, 28, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 28, 28, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 14, 14, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 14, 14, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 14, 14, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 14, 14, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 14, 14, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 14, 14, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv4_block3_concat[0][0]']
# ...
#
#  conv5_block10_0_bn (BatchN  (None, 7, 7, 800)            3200      ['conv5_block9_concat[0][0]']
#  ormalization)
#
#  conv5_block10_0_relu (Acti  (None, 7, 7, 800)            0         ['conv5_block10_0_bn[0][0]']
#  vation)
#
#  conv5_block10_1_conv (Conv  (None, 7, 7, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 7, 7, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 7, 7, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 7, 7, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 7, 7, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 7, 7, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 7, 7, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 7, 7, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 7, 7, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 7, 7, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 7, 7, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 7, 7, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 7, 7, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 7, 7, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 7, 7, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 7, 7, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 7, 7, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 7, 7, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 7, 7, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 7, 7, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 7, 7, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 7, 7, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 7, 7, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 7, 7, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 7, 7, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 7, 7, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 7, 7, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 7, 7, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 7, 7, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 7, 7, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 7, 7, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 7)                    7175      ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 7044679 (26.87 MB)
# Trainable params: 7175 (28.03 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
#Define Callback

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Callback to reduce the learning rate when validation loss plateaus
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=np.sqrt(0.1),  # Factor to reduce learning rate
    patience=5,
    verbose=1
)

# Callback to stop training when validation loss doesn't improve
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,  # Number of epochs to wait before stopping
    verbose=1,
    restore_best_weights=True
)

# %%
#Define the optimizer
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### Compiling the Model
# We use `adam` Optimizer, `SparseCategoricalCrossentropy` for losses, `accuracy` as a metric

# %%
model_tl.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model_tl.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=2,
    epochs=epochs,
    class_weight = class_weights,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/100
# 172/172 - 32s - loss: 1.0153 - accuracy: 0.6403 - val_loss: 0.6311 - val_accuracy: 0.7707 - lr: 0.0010 - 32s/epoch - 189ms/step
# Epoch 2/100
# 172/172 - 24s - loss: 0.5373 - accuracy: 0.8109 - val_loss: 0.4542 - val_accuracy: 0.8473 - lr: 0.0010 - 24s/epoch - 142ms/step
# Epoch 3/100
# 172/172 - 24s - loss: 0.4291 - accuracy: 0.8546 - val_loss: 0.3959 - val_accuracy: 0.8619 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 4/100
# 172/172 - 24s - loss: 0.3709 - accuracy: 0.8714 - val_loss: 0.3497 - val_accuracy: 0.8804 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 5/100
# 172/172 - 24s - loss: 0.3299 - accuracy: 0.8879 - val_loss: 0.3325 - val_accuracy: 0.8900 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 6/100
# 172/172 - 24s - loss: 0.3025 - accuracy: 0.8961 - val_loss: 0.2904 - val_accuracy: 0.9040 - lr: 0.0010 - 24s/epoch - 142ms/step
# Epoch 7/100
# 172/172 - 24s - loss: 0.2788 - accuracy: 0.9046 - val_loss: 0.2899 - val_accuracy: 0.9059 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 8/100
# 172/172 - 24s - loss: 0.2609 - accuracy: 0.9100 - val_loss: 0.2635 - val_accuracy: 0.9149 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 9/100
# 172/172 - 24s - loss: 0.2464 - accuracy: 0.9150 - val_loss: 0.2465 - val_accuracy: 0.9238 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 10/100
# 172/172 - 24s - loss: 0.2336 - accuracy: 0.9193 - val_loss: 0.2386 - val_accuracy: 0.9180 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 11/100
# 172/172 - 24s - loss: 0.2215 - accuracy: 0.9238 - val_loss: 0.2136 - val_accuracy: 0.9343 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 12/100
# 172/172 - 24s - loss: 0.2138 - accuracy: 0.9261 - val_loss: 0.2219 - val_accuracy: 0.9311 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 13/100
# 172/172 - 24s - loss: 0.2045 - accuracy: 0.9285 - val_loss: 0.2056 - val_accuracy: 0.9375 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 14/100
# 172/172 - 24s - loss: 0.1968 - accuracy: 0.9314 - val_loss: 0.1906 - val_accuracy: 0.9420 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 15/100
# 172/172 - 24s - loss: 0.1896 - accuracy: 0.9341 - val_loss: 0.2019 - val_accuracy: 0.9273 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 16/100
# 172/172 - 24s - loss: 0.1829 - accuracy: 0.9395 - val_loss: 0.1802 - val_accuracy: 0.9394 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 17/100
# 172/172 - 24s - loss: 0.1804 - accuracy: 0.9382 - val_loss: 0.1858 - val_accuracy: 0.9369 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 18/100
# 172/172 - 24s - loss: 0.1735 - accuracy: 0.9400 - val_loss: 0.1686 - val_accuracy: 0.9458 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 19/100
# 172/172 - 24s - loss: 0.1687 - accuracy: 0.9412 - val_loss: 0.1709 - val_accuracy: 0.9480 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 20/100
# 172/172 - 24s - loss: 0.1639 - accuracy: 0.9425 - val_loss: 0.1704 - val_accuracy: 0.9480 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 21/100
# 172/172 - 24s - loss: 0.1614 - accuracy: 0.9442 - val_loss: 0.1585 - val_accuracy: 0.9512 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 22/100
# 172/172 - 24s - loss: 0.1560 - accuracy: 0.9469 - val_loss: 0.1682 - val_accuracy: 0.9452 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 23/100
# 172/172 - 24s - loss: 0.1541 - accuracy: 0.9461 - val_loss: 0.1687 - val_accuracy: 0.9464 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 24/100
# 172/172 - 24s - loss: 0.1506 - accuracy: 0.9483 - val_loss: 0.1614 - val_accuracy: 0.9448 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 25/100
# 172/172 - 24s - loss: 0.1486 - accuracy: 0.9487 - val_loss: 0.1725 - val_accuracy: 0.9330 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 26/100
# 172/172 - 24s - loss: 0.1460 - accuracy: 0.9493 - val_loss: 0.1430 - val_accuracy: 0.9570 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 27/100
# 172/172 - 24s - loss: 0.1447 - accuracy: 0.9491 - val_loss: 0.1452 - val_accuracy: 0.9547 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 28/100
# 172/172 - 24s - loss: 0.1402 - accuracy: 0.9532 - val_loss: 0.1456 - val_accuracy: 0.9570 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 29/100
# 172/172 - 24s - loss: 0.1377 - accuracy: 0.9526 - val_loss: 0.1471 - val_accuracy: 0.9490 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 30/100
# 172/172 - 24s - loss: 0.1355 - accuracy: 0.9519 - val_loss: 0.1440 - val_accuracy: 0.9560 - lr: 0.0010 - 24s/epoch - 140ms/step
# Epoch 31/100
# 172/172 - 24s - loss: 0.1328 - accuracy: 0.9541 - val_loss: 0.1362 - val_accuracy: 0.9550 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 32/100
# 172/172 - 24s - loss: 0.1320 - accuracy: 0.9522 - val_loss: 0.1434 - val_accuracy: 0.9515 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 33/100
# 172/172 - 24s - loss: 0.1296 - accuracy: 0.9549 - val_loss: 0.1300 - val_accuracy: 0.9585 - lr: 0.0010 - 24s/epoch - 142ms/step
# Epoch 34/100
# 172/172 - 24s - loss: 0.1272 - accuracy: 0.9552 - val_loss: 0.1309 - val_accuracy: 0.9624 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 35/100
# 172/172 - 24s - loss: 0.1254 - accuracy: 0.9568 - val_loss: 0.1359 - val_accuracy: 0.9570 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 36/100
# 172/172 - 24s - loss: 0.1234 - accuracy: 0.9580 - val_loss: 0.1341 - val_accuracy: 0.9573 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 37/100
# 172/172 - 24s - loss: 0.1233 - accuracy: 0.9557 - val_loss: 0.1501 - val_accuracy: 0.9515 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 38/100
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 172/172 - 24s - loss: 0.1227 - accuracy: 0.9578 - val_loss: 0.1307 - val_accuracy: 0.9605 - lr: 0.0010 - 24s/epoch - 141ms/step
# Epoch 39/100
# 172/172 - 24s - loss: 0.1154 - accuracy: 0.9611 - val_loss: 0.1269 - val_accuracy: 0.9624 - lr: 3.1623e-04 - 24s/epoch - 142ms/step
# Epoch 40/100
# 172/172 - 24s - loss: 0.1144 - accuracy: 0.9605 - val_loss: 0.1244 - val_accuracy: 0.9621 - lr: 3.1623e-04 - 24s/epoch - 142ms/step
# Epoch 41/100
# 172/172 - 24s - loss: 0.1142 - accuracy: 0.9610 - val_loss: 0.1249 - val_accuracy: 0.9636 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 42/100
# 172/172 - 24s - loss: 0.1131 - accuracy: 0.9608 - val_loss: 0.1274 - val_accuracy: 0.9627 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 43/100
# 172/172 - 24s - loss: 0.1137 - accuracy: 0.9622 - val_loss: 0.1236 - val_accuracy: 0.9621 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 44/100
# 172/172 - 24s - loss: 0.1127 - accuracy: 0.9626 - val_loss: 0.1238 - val_accuracy: 0.9636 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 45/100
# 172/172 - 24s - loss: 0.1128 - accuracy: 0.9618 - val_loss: 0.1242 - val_accuracy: 0.9624 - lr: 3.1623e-04 - 24s/epoch - 140ms/step
# Epoch 46/100
# 172/172 - 24s - loss: 0.1115 - accuracy: 0.9618 - val_loss: 0.1291 - val_accuracy: 0.9598 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 47/100
# 172/172 - 24s - loss: 0.1118 - accuracy: 0.9618 - val_loss: 0.1194 - val_accuracy: 0.9640 - lr: 3.1623e-04 - 24s/epoch - 142ms/step
# Epoch 48/100
# 172/172 - 24s - loss: 0.1108 - accuracy: 0.9611 - val_loss: 0.1196 - val_accuracy: 0.9659 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 49/100
# 172/172 - 24s - loss: 0.1103 - accuracy: 0.9628 - val_loss: 0.1206 - val_accuracy: 0.9643 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 50/100
# 172/172 - 24s - loss: 0.1102 - accuracy: 0.9638 - val_loss: 0.1328 - val_accuracy: 0.9566 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 51/100
# 172/172 - 24s - loss: 0.1104 - accuracy: 0.9623 - val_loss: 0.1247 - val_accuracy: 0.9643 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 52/100
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 172/172 - 24s - loss: 0.1097 - accuracy: 0.9627 - val_loss: 0.1219 - val_accuracy: 0.9630 - lr: 3.1623e-04 - 24s/epoch - 141ms/step
# Epoch 53/100
# 172/172 - 24s - loss: 0.1078 - accuracy: 0.9643 - val_loss: 0.1211 - val_accuracy: 0.9640 - lr: 1.0000e-04 - 24s/epoch - 141ms/step
# Epoch 54/100
# 172/172 - 24s - loss: 0.1074 - accuracy: 0.9642 - val_loss: 0.1230 - val_accuracy: 0.9627 - lr: 1.0000e-04 - 24s/epoch - 141ms/step
# Epoch 55/100
# 172/172 - 24s - loss: 0.1069 - accuracy: 0.9646 - val_loss: 0.1173 - val_accuracy: 0.9659 - lr: 1.0000e-04 - 24s/epoch - 141ms/step
# Epoch 56/100
# 172/172 - 24s - loss: 0.1071 - accuracy: 0.9647 - val_loss: 0.1206 - val_accuracy: 0.9652 - lr: 1.0000e-04 - 24s/epoch - 140ms/step
# Epoch 57/100
# 172/172 - 24s - loss: 0.1071 - accuracy: 0.9642 - val_loss: 0.1218 - val_accuracy: 0.9624 - lr: 1.0000e-04 - 24s/epoch - 141ms/step
# Epoch 58/100
# 172/172 - 24s - loss: 0.1066 - accuracy: 0.9652 - val_loss: 0.1203 - val_accuracy: 0.9630 - lr: 1.0000e-04 - 24s/epoch - 141ms/step
# Epoch 59/100
# 172/172 - 24s - loss: 0.1066 - accuracy: 0.9645 - val_loss: 0.1217 - val_accuracy: 0.9630 - lr: 1.0000e-04 - 24s/epoch - 141ms/step
# Epoch 60/100
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 172/172 - 24s - loss: 0.1066 - accuracy: 0.9648 - val_loss: 0.1211 - val_accuracy: 0.9627 - lr: 1.0000e-04 - 24s/epoch - 141ms/step
# Epoch 61/100
# 172/172 - 24s - loss: 0.1059 - accuracy: 0.9646 - val_loss: 0.1194 - val_accuracy: 0.9640 - lr: 3.1623e-05 - 24s/epoch - 141ms/step
# Epoch 62/100
# 172/172 - 24s - loss: 0.1059 - accuracy: 0.9648 - val_loss: 0.1190 - val_accuracy: 0.9643 - lr: 3.1623e-05 - 24s/epoch - 141ms/step
# Epoch 63/100
# 172/172 - 24s - loss: 0.1059 - accuracy: 0.9643 - val_loss: 0.1189 - val_accuracy: 0.9643 - lr: 3.1623e-05 - 24s/epoch - 140ms/step
# Epoch 64/100
# 172/172 - 24s - loss: 0.1058 - accuracy: 0.9649 - val_loss: 0.1189 - val_accuracy: 0.9643 - lr: 3.1623e-05 - 24s/epoch - 140ms/step
# Epoch 65/100
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# Restoring model weights from the end of the best epoch: 55.
# 172/172 - 24s - loss: 0.1058 - accuracy: 0.9648 - val_loss: 0.1189 - val_accuracy: 0.9646 - lr: 3.1623e-05 - 24s/epoch - 142ms/step
# Epoch 65: early stopping

# %% [markdown]
# Evaluate the model

# %%
scores = model_tl.evaluate(test_ds)
# Out:
# 25/25 [==============================] - 3s 113ms/step - loss: 0.1334 - accuracy: 0.9609

# %% [markdown]
# ### Run prediction on a sample image

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model_tl.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Healthy Fruit
# 2/2 [==============================] - 2s 53ms/step
# predicted label: Healthy Fruit

# %% [markdown]
# # Plotting the accuracy, loss and the epoch curves

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np



# Get true and predicted labels
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model_tl.predict(images)  # Get model predictions
    y_pred.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes

# Confusion Matrix with class names
cf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf_matrix, annot=True, cmap="Blues", fmt="g", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 2s 2s/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 48ms/step

# %% [markdown]
# Classification Report

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.99      0.99      0.99        67
#       Black spot       0.93      0.92      0.92       171
#  European Canker       1.00      1.00      1.00       220
#    Healthy Fruit       0.97      0.99      0.98       223
#     Healthy Leaf       0.94      0.94      0.94       284
# Leaf spot (scab)       0.97      0.94      0.95       330
#    Mosaic virus        0.95      0.98      0.96       267
#
#         accuracy                           0.96      1562
#        macro avg       0.96      0.96      0.96      1562
#     weighted avg       0.96      0.96      0.96      1562

# %% [markdown]
# ROC - AUC

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true = []
y_pred_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model_tl.predict(images)  # Get model predictions (probabilities)
    y_pred_probs.extend(predictions)  # Collect predicted probabilities

# Convert to NumPy arrays
y_true = np.array(y_true)  # Ensure true labels are arrays
y_pred_probs = np.array(y_pred_probs)  # Ensure predicted probabilities are arrays

# Binarize the true labels to get a one-hot encoded representation
y_true_bin = label_binarize(y_true, classes=list(range(20)))

# Initialize ROC and AUC data
fpr = dict()  # False positive rates
tpr = dict()  # True positive rates
roc_auc = dict()  # AUC for each class

# Compute ROC and AUC for each class
for i in range(classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])  # ROC data for each class
    roc_auc[i] = auc(fpr[i], tpr[i])  # AUC for each class

# Compute macro-average AUC
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(classes)]))
mean_tpr = np.zeros_like(all_fpr)

# Compute mean true positive rates
for i in range(classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= classes  # Normalize by the number of classes
macro_auc = auc(all_fpr, mean_tpr)  # Macro-average AUC

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')  # Label with class names and AUC

# Plot the macro-average ROC curve
plt.plot(all_fpr, mean_tpr, color='k', linestyle='--', label=f'Macro-average ROC (AUC = {macro_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 49ms/step

# %% [markdown]
# Write a function for inference for the better model -

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %% [markdown]
# **Now run inference on few sample images from the traing from scratch model**

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
