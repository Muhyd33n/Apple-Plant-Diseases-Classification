# %% [markdown]
# # Apple Leaf and Fruit Diseases Classification Using VGG16

# %% [markdown]
# Dataset credits: https://github.com/hsaleem1/NZDLPlantDisease-v1

# %% [markdown]
# Mount Google Drive

# %%
#Mount google drive to google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path ="/content/drive/MyDrive/Classroom/NewNZdataset"

# %% [markdown]
# ### Import all the Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Flatten
from tensorflow.keras.models import Model

# %% [markdown]
# ### Set all the Constants

# %%
BATCH_SIZE = 64
IMAGE_SIZE = 224  #---“input shape has to be `(224, 224, 3)” → VGG16
CHANNELS=3
epochs=100
classes =7

# %% [markdown]
# ### Import data into tensorflow dataset object

# %% [markdown]
# We will use image_dataset_from_directory api to load all images in tensorflow dataset: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 15706 files belonging to 7 classes.

# %%
#Print class names
class_names = dataset.class_names

class_names
# Out:
# ['Black rot',
#  'Black spot',
#  'European Canker',
#  'Healthy Fruit',
#  'Healthy Leaf',
#  'Leaf spot (scab)',
#  'Mosaic virus ']

# %% [markdown]
# EXPLORATORY DATA ANALYSIS (EDA)

# %%
#Total number of images ≈ Number of batches × Batch size
len(dataset)
# Out:
# 246

# %%
# Count the number of images per class
class_counts = dict.fromkeys(class_names, 0)

for images, labels in dataset:
    for label in labels:
        label = int(label.numpy())  # Convert to int if necessary
        class_counts[class_names[label]] += 1

# Plotting the class distribution
plt.figure(figsize=(8, 4))
plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Count the Element in Each Class

# %%
import tensorflow as tf
from collections import defaultdict

class_counts = defaultdict(int)

# Iterate through the dataset to count occurrences of each class
for batch in dataset:
    # Extract labels from the batch
    labels = batch[1]

    # Count occurrences of each label in this batch
    for label in labels:
        class_counts[label.numpy()] += 1

# Display the counts for each class with class names
print("Class counts:")
for class_index, count in class_counts.items():
    class_name = class_names[class_index]
    print(f"{class_name}: {count} images")
# Out:
# Class counts:
# Leaf spot (scab): 3368 images
# European Canker: 2147 images
# Healthy Leaf: 2765 images
# Healthy Fruit: 2282 images
# Mosaic virus : 2636 images
# Black rot: 742 images
# Black spot: 1766 images

# %% [markdown]
# # Defining Class Weights
#
# There are many more observations of the Leaf spot class, and so this will have a larger impact on the overall value of the loss function than observations belonging to the other classes. the weight is going to be used for training the models

# %%
# Example class counts (use your actual counts)
class_counts = {
    "Healthy Leaf": 2765,
    "Healthy Fruit": 2282,
    "Black spot": 1766,
    "European Canker": 2147,
    "Mosaic virus": 2636,
    "Leaf spot (scab)": 3368,
    "Black rot": 742,
}

# Total number of samples and unique classes
total_samples = sum(class_counts.values())
num_classes = len(class_counts)

# Calculate class weights
class_weights = {}
for i, (class_name, count) in enumerate(class_counts.items()):
    weight = total_samples / (num_classes * count)
    class_weights[i] = weight

# %%
#Check the shape of the first batch
for image_batch, labels_batch in dataset.take(1):
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
for image_batch in dataset.take(1):
    print(image_batch[0].numpy())
# Out:
# [[[[1.69005112e+02 2.06719391e+02 6.97091904e+01]
#    [1.58362228e+02 1.89790802e+02 8.76887665e+01]
#    [8.69948959e+01 1.07234688e+02 5.43265305e+01]
#    ...
#    [2.49147964e+02 2.52122452e+02 1.97510239e+02]
#    [2.51933701e+02 2.54147980e+02 2.05688828e+02]
#    [2.54438812e+02 2.54714279e+02 2.14602173e+02]]
#
#   [[1.51438782e+02 1.88954086e+02 5.46785736e+01]
#    [1.63571426e+02 1.95045914e+02 9.24387741e+01]
#    [1.18632652e+02 1.39418365e+02 8.27806091e+01]
#    ...
#    [1.49286938e+01 2.47756710e+01 1.67807503e+01]
#    [2.83522167e+01 3.97552834e+01 2.94491310e+01]]
#
#   ...
#
#   [[2.09760162e+02 2.51193878e+02 1.97596924e+02]
#    [2.15510178e+02 2.53989777e+02 2.01938751e+02]
#    [2.22571381e+02 2.55000000e+02 2.08571381e+02]
#    ...
#    [1.59586716e+02 2.52989746e+02 6.00867958e+01]
#    [1.63642868e+02 2.53362228e+02 7.16531601e+01]
#    [1.62724487e+02 2.51127533e+02 7.54133606e+01]]
#
#   [[2.06729584e+02 2.52714294e+02 1.97943878e+02]
#    [2.11928558e+02 2.54663269e+02 2.00903061e+02]
#    [2.17867325e+02 2.55000000e+02 2.05515289e+02]
#    ...
#    [1.59280609e+02 2.53943878e+02 6.25154037e+01]
#    [1.62311249e+02 2.53076538e+02 7.41225433e+01]
#    [1.64673508e+02 2.54260239e+02 8.08164291e+01]]
#
#   [[2.07081650e+02 2.54867386e+02 1.99933701e+02]
#    [2.10158142e+02 2.55000000e+02 2.01586746e+02]
#    [2.15545898e+02 2.55000000e+02 2.04408157e+02]
#    ...
#    [1.60882675e+02 2.54954086e+02 6.56633759e+01]
#    [1.62540833e+02 2.53413254e+02 7.57704926e+01]
#    [1.63994904e+02 2.53132629e+02 8.25715332e+01]]]]

# %% [markdown]
# As you can see above, each element in the dataset is a tuple. First element is a batch of 64 elements of images. Second element is a batch of 64 elements of class labels

# %% [markdown]
# ### Visualize some of the images from our dataset

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ### Function to Split Dataset
#
# Dataset should be bifurcated into 3 subsets, namely:
# 1. Training: Dataset to be used while training
# 2. Validation: Dataset to be tested against while training
# 3. Test: Dataset to be tested against after we trained a model

# %%
def get_dataset_partitions_tf(ds, train_split=0.7, val_split=0.2, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 172

# %%
len(val_ds)
# Out:
# 49

# %%
len(test_ds)
# Out:
# 25

# %% [markdown]
# ### Cache, Shuffle, and Prefetch the Dataset

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### Creating a Layer for Normalization
# Before we feed our images to network,  to improve model performance, we should normalize the image pixel value (keeping them in range 0 and 1 by dividing by 256).
# This should happen while training as well as inference. Hence we can add that as a layer in our Sequential Model.

# %%
#normalization
rescale = tf.keras.Sequential([
layers.experimental.preprocessing.Rescaling(1./255),
])

# %% [markdown]
# # Building the Model

# %%
# import necessary layers

from tensorflow.keras.layers import Input, Conv2D
from tensorflow.keras.layers import MaxPool2D, Dense, GlobalAvgPool2D
from tensorflow.keras import Model

# %% [markdown]
# Building the VGG16 Model from scratch

# %%
# input
input = Input(shape =(224,224,3))
input=rescale(input)

# %%
# 1st Conv Block

x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(input)
x = Conv2D (filters =64, kernel_size =3, padding ='same', activation='relu')(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# %%
# 2nd Conv Block

x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =128, kernel_size =3, padding ='same', activation='relu')(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# %%
# 3rd Conv block
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =256, kernel_size =3, padding ='same', activation='relu')(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# %%
# 4th Conv block

x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# 5th Conv block

x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = Conv2D (filters =512, kernel_size =3, padding ='same', activation='relu')(x)
x = MaxPool2D(pool_size =2, strides =2, padding ='same')(x)

# %%
# Fully connected layers
x = GlobalAvgPool2D()(x)
x = Dense(units = 4096, activation ='relu')(x)
x = Dense(units = 4096, activation ='relu')(x)
output = Dense(units = classes, activation ='softmax')(x)

# %%
# creating the model

model = Model (inputs=input, outputs =output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 256)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 512)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 512)         0
#  g2D)
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 7)                 28679
#
# =================================================================
# Total params: 33625927 (128.27 MB)
# Trainable params: 33625927 (128.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Building the Model

# %% [markdown]
# ### Model Architecture
# We use a CNN coupled with a Softmax activation in the output layer. We also add the initial layers for resizing, normalization and Data Augmentation.

# %% [markdown]
# # Training from Scratch

# %% [markdown]
# # Defining Callbacks
#
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %%
import numpy as np
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Callback to reduce the learning rate when validation loss plateaus
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=np.sqrt(0.1),  # Factor to reduce learning rate
    patience=5,
    verbose=1
)

# Callback to stop training when validation loss doesn't improve
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,  # Number of epochs to wait before stopping
    verbose=1,
    restore_best_weights=True
)

# %% [markdown]
# Defining the Optimizer

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)

# %%
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=2,
    epochs=epochs,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/100
# 172/172 - 156s - loss: 15.5343 - accuracy: 0.1962 - val_loss: 1.8346 - val_accuracy: 0.2200 - lr: 0.0010 - 156s/epoch - 905ms/step
# Epoch 2/100
# 172/172 - 85s - loss: 1.8836 - accuracy: 0.2048 - val_loss: 1.8829 - val_accuracy: 0.1980 - lr: 0.0010 - 85s/epoch - 493ms/step
# Epoch 3/100
# 172/172 - 84s - loss: 1.8902 - accuracy: 0.2103 - val_loss: 1.8843 - val_accuracy: 0.1789 - lr: 0.0010 - 84s/epoch - 491ms/step
# Epoch 4/100
# 172/172 - 84s - loss: 1.8780 - accuracy: 0.2079 - val_loss: 1.8870 - val_accuracy: 0.2200 - lr: 0.0010 - 84s/epoch - 491ms/step
# Epoch 5/100
# 172/172 - 84s - loss: 1.8786 - accuracy: 0.2098 - val_loss: 1.8824 - val_accuracy: 0.2200 - lr: 0.0010 - 84s/epoch - 490ms/step
# Epoch 6/100
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 172/172 - 84s - loss: 1.9079 - accuracy: 0.2108 - val_loss: 1.8820 - val_accuracy: 0.2200 - lr: 0.0010 - 84s/epoch - 489ms/step
# Epoch 7/100
# 172/172 - 83s - loss: 1.8772 - accuracy: 0.2115 - val_loss: 1.8810 - val_accuracy: 0.2200 - lr: 3.1623e-04 - 83s/epoch - 482ms/step
# Epoch 8/100
# 172/172 - 83s - loss: 1.8769 - accuracy: 0.2115 - val_loss: 1.8806 - val_accuracy: 0.2200 - lr: 3.1623e-04 - 83s/epoch - 483ms/step
# Epoch 9/100
# 172/172 - 84s - loss: 1.8757 - accuracy: 0.2111 - val_loss: 1.8783 - val_accuracy: 0.2200 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 10/100
# 172/172 - 84s - loss: 1.8016 - accuracy: 0.2424 - val_loss: 1.5201 - val_accuracy: 0.3441 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 11/100
# 172/172 - 84s - loss: 1.2914 - accuracy: 0.4337 - val_loss: 1.2800 - val_accuracy: 0.4340 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 12/100
# 172/172 - 84s - loss: 1.1031 - accuracy: 0.5233 - val_loss: 1.0945 - val_accuracy: 0.5210 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 13/100
# 172/172 - 84s - loss: 1.0114 - accuracy: 0.5604 - val_loss: 0.9140 - val_accuracy: 0.6020 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 14/100
# 172/172 - 84s - loss: 0.9355 - accuracy: 0.6078 - val_loss: 0.8779 - val_accuracy: 0.6505 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 15/100
# 172/172 - 84s - loss: 0.8136 - accuracy: 0.6763 - val_loss: 0.6968 - val_accuracy: 0.7299 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 16/100
# 172/172 - 84s - loss: 0.6854 - accuracy: 0.7355 - val_loss: 0.6005 - val_accuracy: 0.7771 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 17/100
# 172/172 - 84s - loss: 0.5627 - accuracy: 0.7907 - val_loss: 0.4600 - val_accuracy: 0.8339 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 18/100
# 172/172 - 84s - loss: 0.4598 - accuracy: 0.8365 - val_loss: 0.4100 - val_accuracy: 0.8524 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 19/100
# 172/172 - 84s - loss: 0.3716 - accuracy: 0.8641 - val_loss: 0.3453 - val_accuracy: 0.8839 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 20/100
# 172/172 - 84s - loss: 0.2980 - accuracy: 0.8899 - val_loss: 0.2520 - val_accuracy: 0.9152 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 21/100
# 172/172 - 85s - loss: 0.2365 - accuracy: 0.9119 - val_loss: 0.2100 - val_accuracy: 0.9260 - lr: 3.1623e-04 - 85s/epoch - 491ms/step
# Epoch 22/100
# 172/172 - 84s - loss: 0.1905 - accuracy: 0.9309 - val_loss: 0.2566 - val_accuracy: 0.9158 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch
- lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 45/100
# 172/172 - 84s - loss: 0.0526 - accuracy: 0.9765 - val_loss: 0.1207 - val_accuracy: 0.9665 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 46/100
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 172/172 - 84s - loss: 0.0654 - accuracy: 0.9728 - val_loss: 0.1266 - val_accuracy: 0.9659 - lr: 3.1623e-04 - 84s/epoch - 491ms/step
# Epoch 47/100
# 172/172 - 84s - loss: 0.0257 - accuracy: 0.9857 - val_loss: 0.0999 - val_accuracy: 0.9754 - lr: 1.0000e-04 - 84s/epoch - 491ms/step
# Epoch 48/100
# 172/172 - 84s - loss: 0.0207 - accuracy: 0.9861 - val_loss: 0.1073 - val_accuracy: 0.9710 - lr: 1.0000e-04 - 84s/epoch - 491ms/step
# Epoch 49/100
# 172/172 - 84s - loss: 0.0204 - accuracy: 0.9855 - val_loss: 0.0999 - val_accuracy: 0.9774 - lr: 1.0000e-04 - 84s/epoch - 491ms/step
# Epoch 50/100
# 172/172 - 84s - loss: 0.0204 - accuracy: 0.9864 - val_loss: 0.1015 - val_accuracy: 0.9770 - lr: 1.0000e-04 - 84s/epoch - 491ms/step
# Epoch 51/100
# 172/172 - 84s - loss: 0.0198 - accuracy: 0.9852 - val_loss: 0.1030 - val_accuracy: 0.9754 - lr: 1.0000e-04 - 84s/epoch - 490ms/step
# Epoch 52/100
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 172/172 - 84s - loss: 0.0196 - accuracy: 0.9866 - val_loss: 0.1009 - val_accuracy: 0.9754 - lr: 1.0000e-04 - 84s/epoch - 491ms/step
# Epoch 53/100
# 172/172 - 84s - loss: 0.0183 - accuracy: 0.9872 - val_loss: 0.1022 - val_accuracy: 0.9774 - lr: 3.1623e-05 - 84s/epoch - 491ms/step
# Epoch 54/100
# 172/172 - 84s - loss: 0.0181 - accuracy: 0.9883 - val_loss: 0.1065 - val_accuracy: 0.9761 - lr: 3.1623e-05 - 84s/epoch - 491ms/step
# Epoch 55/100
# 172/172 - 84s - loss: 0.0180 - accuracy: 0.9878 - val_loss: 0.1076 - val_accuracy: 0.9770 - lr: 3.1623e-05 - 84s/epoch - 491ms/step
# Epoch 56/100
# 172/172 - 84s - loss: 0.0181 - accuracy: 0.9875 - val_loss: 0.1100 - val_accuracy: 0.9770 - lr: 3.1623e-05 - 84s/epoch - 491ms/step
# Epoch 57/100
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# 172/172 - 84s - loss: 0.0180 - accuracy: 0.9868 - val_loss: 0.1101 - val_accuracy: 0.9767 - lr: 3.1623e-05 - 84s/epoch - 491ms/step
# Epoch 58/100
# 172/172 - 84s - loss: 0.0176 - accuracy: 0.9886 - val_loss: 0.1108 - val_accuracy: 0.9777 - lr: 1.0000e-05 - 84s/epoch - 491ms/step
# Epoch 59/100
# Restoring model weights from the end of the best epoch: 49.
# 172/172 - 85s - loss: 0.0174 - accuracy: 0.9883 - val_loss: 0.1123 - val_accuracy: 0.9783 - lr: 1.0000e-05 - 85s/epoch - 491ms/step
# Epoch 59: early stopping

# %%
scores = model.evaluate(test_ds)
# Out:
# 25/25 [==============================] - 27s 324ms/step - loss: 0.0940 - accuracy: 0.9699

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Leaf spot (scab)
# 2/2 [==============================] - 5s 10ms/step
# predicted label: Leaf spot (scab)

# %% [markdown]
# Plotting training and validation accuracy, loss and learning rate

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# COnfusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np



# Get true and predicted labels
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model.predict(images)  # Get model predictions
    y_pred.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes

# Confusion Matrix with class names
cf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf_matrix, annot=True, cmap="Blues", fmt="g", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step

# %% [markdown]
# Classification Report with Precision and Recall

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.98      0.96      0.97        67
#       Black spot       0.95      0.93      0.94       171
#  European Canker       0.98      0.99      0.99       220
#    Healthy Fruit       0.96      0.98      0.97       223
#     Healthy Leaf       0.97      0.96      0.97       284
# Leaf spot (scab)       0.98      1.00      0.99       330
#    Mosaic virus        0.97      0.95      0.96       267
#
#         accuracy                           0.97      1562
#        macro avg       0.97      0.97      0.97      1562
#     weighted avg       0.97      0.97      0.97      1562

# %% [markdown]
# ROC AUC

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true = []
y_pred_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model.predict(images)  # Get model predictions (probabilities)
    y_pred_probs.extend(predictions)  # Collect predicted probabilities

# Convert to NumPy arrays
y_true = np.array(y_true)  # Ensure true labels are arrays
y_pred_probs = np.array(y_pred_probs)  # Ensure predicted probabilities are arrays

# Binarize the true labels to get a one-hot encoded representation
y_true_bin = label_binarize(y_true, classes=list(range(20)))

# Initialize ROC and AUC data
fpr = dict()  # False positive rates
tpr = dict()  # True positive rates
roc_auc = dict()  # AUC for each class

# Compute ROC and AUC for each class
for i in range(classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])  # ROC data for each class
    roc_auc[i] = auc(fpr[i], tpr[i])  # AUC for each class

# Compute macro-average AUC
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(classes)]))
mean_tpr = np.zeros_like(all_fpr)

# Compute mean true positive rates
for i in range(classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= classes  # Normalize by the number of classes
macro_auc = auc(all_fpr, mean_tpr)  # Macro-average AUC

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')  # Label with class names and AUC

# Plot the macro-average ROC curve
plt.plot(all_fpr, mean_tpr, color='k', linestyle='--', label=f'Macro-average ROC (AUC = {macro_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step

# %% [markdown]
# # Transfer Learning

# %%
from keras.layers import Input,Rescaling

# this could also be the output a different Keras model or layer
input = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
x = rescale(input)

# %%
# Load the vgg16 pre-trained model without the top layer (fully connected layers)
vgg =VGG16(input_tensor=x, weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
# Freeze the layers of vgg
for layer in vgg.layers:
  layer.trainable =False

# %%
x = GlobalAveragePooling2D()(vgg.output)
prediction = Dense(classes, activation ='softmax')(x)
#create a model object
model_tl =Model(inputs =vgg.input, outputs =prediction)
#View the structure of the model
model_tl.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 14718279 (56.15 MB)
# Trainable params: 3591 (14.03 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# Initialize the Optimizer

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### Compiling the Model
# We use `adam` Optimizer, `SparseCategoricalCrossentropy` for losses, `accuracy` as a metric

# %%
model_tl.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model_tl.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=2,
    epochs=epochs,
    class_weight = class_weights,
    callbacks=[reduce_lr, early_stopping])
# Out:
# Epoch 1/100
# 172/172 - 45s - loss: 1.8279 - accuracy: 0.2577 - val_loss: 1.4917 - val_accuracy: 0.3237 - lr: 0.0010 - 45s/epoch - 262ms/step
# Epoch 2/100
# 172/172 - 43s - loss: 1.3868 - accuracy: 0.4620 - val_loss: 1.2126 - val_accuracy: 0.5287 - lr: 0.0010 - 43s/epoch - 248ms/step
# Epoch 3/100
# 172/172 - 44s - loss: 1.1808 - accuracy: 0.5621 - val_loss: 1.0856 - val_accuracy: 0.5775 - lr: 0.0010 - 44s/epoch - 254ms/step
# Epoch 4/100
# 172/172 - 44s - loss: 1.0550 - accuracy: 0.6227 - val_loss: 0.9730 - val_accuracy: 0.6457 - lr: 0.0010 - 44s/epoch - 253ms/step
# Epoch 5/100
# 172/172 - 43s - loss: 0.9690 - accuracy: 0.6557 - val_loss: 0.9243 - val_accuracy: 0.6540 - lr: 0.0010 - 43s/epoch - 252ms/step
# Epoch
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 172/172 - 43s - loss: 0.3940 - accuracy: 0.8638 - val_loss: 0.4182 - val_accuracy: 0.8568 - lr: 3.1623e-04 - 43s/epoch - 253ms/step
# Epoch 69/100
# 172/172 - 43s - loss: 0.3926 - accuracy: 0.8634 - val_loss: 0.4182 - val_accuracy: 0.8562 - lr: 1.0000e-04 - 43s/epoch - 253ms/step
# Epoch 70/100
# 172/172 - 43s - loss: 0.3923 - accuracy: 0.8650 - val_loss: 0.4173 - val_accuracy: 0.8587 - lr: 1.0000e-04 - 43s/epoch - 252ms/step
# Epoch 71/100
# 172/172 - 43s - loss: 0.3921 - accuracy: 0.8652 - val_loss: 0.4203 - val_accuracy: 0.8559 - lr: 1.0000e-04 - 43s/epoch - 252ms/step
# Epoch 72/100
# 172/172 - 44s - loss: 0.3917 - accuracy: 0.8644 - val_loss: 0.4221 - val_accuracy: 0.8559 - lr: 1.0000e-04 - 44s/epoch - 253ms/step
# Epoch 73/100
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# Restoring model weights from the end of the best epoch: 63.
# 172/172 - 43s - loss: 0.3916 - accuracy: 0.8650 - val_loss: 0.4179 - val_accuracy: 0.8581 - lr: 1.0000e-04 - 43s/epoch - 253ms/step
# Epoch 73: early stopping

# %%
scores = model_tl.evaluate(test_ds)
# Out:
# 25/25 [==============================] - 4s 176ms/step - loss: 0.4228 - accuracy: 0.8528

# %% [markdown]
# ### Run prediction on a sample image

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model_tl.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: European Canker
# 1/1 [==============================] - 0s 148ms/step
# predicted label: European Canker

# %% [markdown]
# # Plotting the accuracy, loss and the epoch curves

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np



# Get true and predicted labels
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model_tl.predict(images)  # Get model predictions
    y_pred.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes

# Confusion Matrix with class names
cf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf_matrix, annot=True, cmap="Blues", fmt="g", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step

# %% [markdown]
# Classification Report

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.92      0.90      0.91        67
#       Black spot       0.77      0.74      0.75       171
#  European Canker       0.95      0.96      0.95       220
#    Healthy Fruit       0.95      0.96      0.96       223
#     Healthy Leaf       0.76      0.72      0.74       284
# Leaf spot (scab)       0.84      0.77      0.80       330
#    Mosaic virus        0.83      0.98      0.90       267
#
#         accuracy                           0.85      1562
#        macro avg       0.86      0.86      0.86      1562
#     weighted avg       0.85      0.85      0.85      1562

# %% [markdown]
# ROC AUC

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true = []
y_pred_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model_tl.predict(images)  # Get model predictions (probabilities)
    y_pred_probs.extend(predictions)  # Collect predicted probabilities

# Convert to NumPy arrays
y_true = np.array(y_true)  # Ensure true labels are arrays
y_pred_probs = np.array(y_pred_probs)  # Ensure predicted probabilities are arrays

# Binarize the true labels to get a one-hot encoded representation
y_true_bin = label_binarize(y_true, classes=list(range(20)))

# Initialize ROC and AUC data
fpr = dict()  # False positive rates
tpr = dict()  # True positive rates
roc_auc = dict()  # AUC for each class

# Compute ROC and AUC for each class
for i in range(classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])  # ROC data for each class
    roc_auc[i] = auc(fpr[i], tpr[i])  # AUC for each class

# Compute macro-average AUC
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(classes)]))
mean_tpr = np.zeros_like(all_fpr)

# Compute mean true positive rates
for i in range(classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= classes  # Normalize by the number of classes
macro_auc = auc(all_fpr, mean_tpr)  # Macro-average AUC

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')  # Label with class names and AUC

# Plot the macro-average ROC curve
plt.plot(all_fpr, mean_tpr, color='k', linestyle='--', label=f'Macro-average ROC (AUC = {macro_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 87ms/step

# %% [markdown]
# Write a function for inference for the VGG16 tranfer learning

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %% [markdown]
# **Now run inference on few sample images**

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model_tl, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
