# %% [markdown]
# # Apple Leaf and Fruit Diseases Classification Using Xception

# %% [markdown]
# Dataset credits: https://github.com/hsaleem1/NZDLPlantDisease-v1

# %% [markdown]
# Mount Google Drive

# %%
#Mount google drive to google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path ="/content/drive/MyDrive/Classroom/NewNZdataset"

# %% [markdown]
# Xception transfer learning is among the best two models. External_test dataset is used in prediction after evaluating the model with test dataset.

# %%
external_testing = "/content/drive/MyDrive/Classroom/External testing Dataset"

# %% [markdown]
# ### Import all the Dependencies

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# %% [markdown]
# ### Set all the Constants

# %%
BATCH_SIZE = 64
IMAGE_SIZE = 299  #---“input shape has to be `(299, 299 , 3)” → Xception
CHANNELS=3
epochs=100
classes =7

# %% [markdown]
# ### Import data into tensorflow dataset object

# %% [markdown]
# We will use image_dataset_from_directory api to load all images in tensorflow dataset: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 15706 files belonging to 7 classes.

# %% [markdown]
# Loading External testing dataset to Test the best model

# %%
external_test = tf.keras.preprocessing.image_dataset_from_directory(
    external_testing,
    seed=41,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 726 files belonging to 7 classes.

# %%
#Print class names
class_names = dataset.class_names

class_names
# Out:
# ['Black rot',
#  'Black spot',
#  'European Canker',
#  'Healthy Fruit',
#  'Healthy Leaf',
#  'Leaf spot (scab)',
#  'Mosaic virus ']

# %% [markdown]
# EXPLORATORY DATA ANALYSIS (EDA)

# %%
#Total number of images ≈ Number of batches × Batch size
len(dataset)
# Out:
# 246

# %%
# Calculate the number of images per class
class_counts = dict.fromkeys(class_names, 0)

for images, labels in dataset:
    for label in labels:
        label = int(label.numpy())  # Convert to int if necessary
        class_counts[class_names[label]] += 1

# Plotting the class distribution
plt.figure(figsize=(8, 4))
plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Count the Element in Each Class

# %%
import tensorflow as tf
from collections import defaultdict

class_counts = defaultdict(int)

# Iterate through the dataset to count occurrences of each class
for batch in dataset:
    # Extract labels from the batch
    labels = batch[1]

    # Count occurrences of each label in this batch
    for label in labels:
        class_counts[label.numpy()] += 1

# Display the counts for each class with class names
print("Class counts:")
for class_index, count in class_counts.items():
    class_name = class_names[class_index]
    print(f"{class_name}: {count} images")
# Out:
# Class counts:
# Leaf spot (scab): 3368 images
# European Canker: 2147 images
# Healthy Leaf: 2765 images
# Healthy Fruit: 2282 images
# Mosaic virus : 2636 images
# Black rot: 742 images
# Black spot: 1766 images

# %% [markdown]
# # Defining Class Weights
#
# There are many more observations of the Leaf spot class, and so this will have a larger impact on the overall value of the loss function than observations belonging to the other classes. the weight is going to be used for training the models

# %%
# Example class counts (use your actual counts)
class_counts = {
    "Healthy Leaf": 2765,
    "Healthy Fruit": 2282,
    "Black spot": 1766,
    "European Canker": 2147,
    "Mosaic virus": 2636,
    "Leaf spot (scab)": 3368,
    "Black rot": 742,
}

# Total number of samples and unique classes
total_samples = sum(class_counts.values())
num_classes = len(class_counts)

# Calculate class weights
class_weights = {}
for i, (class_name, count) in enumerate(class_counts.items()):
    weight = total_samples / (num_classes * count)
    class_weights[i] = weight

# %%
#Check the shape of the first batch
for image_batch, labels_batch in dataset.take(1):
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
for image_batch in dataset.take(1):
    print(image_batch[0].numpy())
# Out:
# [[


# %% [markdown]
# As you can see above, each element in the dataset is a tuple. First element is a batch of 32 elements of images. Second element is a batch of 64 elements of class labels

# %% [markdown]
# ### Visualize some of the images from our dataset

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %% [markdown]
# ### Function to Split Dataset
#
# Dataset should be bifurcated into 3 subsets, namely:
# 1. Training: Dataset to be used while training
# 2. Validation: Dataset to be tested against while training
# 3. Test: Dataset to be tested against after we trained a model

# %%
def get_dataset_partitions_tf(ds, train_split=0.7, val_split=0.2, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 172

# %%
len(val_ds)
# Out:
# 49

# %%
len(test_ds)
# Out:
# 25

# %% [markdown]
# ### Cache, Shuffle, and Prefetch the Dataset

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
external_test = external_test.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### Creating a Layer for Normalization
# Before we feed our images to network,  to improve model performance, we should normalize the image pixel value (keeping them in range 0 and 1 by dividing by 255).
# This should happen while training as well as inference. Hence we can add that as a layer in our Sequential Model.

# %%
rescale = tf.keras.Sequential([layers.experimental.preprocessing.Rescaling(1./255),])

# %% [markdown]
# ## Building the Model

# %% [markdown]
# ### Model Architecture
# We use a CNN coupled with a Softmax activation in the output layer. We also add the initial layers for resizing, normalization and Data Augmentation.

# %%
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, \
     Add, Dense, BatchNormalization, ReLU, MaxPool2D, GlobalAvgPool2D

# %% [markdown]
# **Training From Scratch**

# %% [markdown]
# Conv-BatchNorm block

# %%
def conv_bn(x, filters, kernel_size, strides=1):
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding='same',
               use_bias=False)(x)
    x = BatchNormalization()(x)
    return x

# %% [markdown]
#  SeparableConv-BatchNorm

# %%
def sep_bn(x, filters, kernel_size, strides=1):
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    return x

# %% [markdown]
# Entry flow

# %%
def entry_flow(x):
    x = conv_bn(x, filters=32, kernel_size=3, strides=2)
    x = ReLU()(x)
    x = conv_bn(x, filters=64, kernel_size=3)
    tensor = ReLU()(x)

    x = sep_bn(tensor, filters=128, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=128, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=128, kernel_size=1, strides=2)

    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, filters=256, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=256, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=256, kernel_size=1, strides=2)

    x = Add()([tensor, x])
    x = ReLU()(x)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=728, kernel_size=1, strides=2)
    x = Add()([tensor, x])

    return x

# %% [markdown]
# Middle Flow

# %%
def middle_flow(tensor):
    for _ in range(8):
        x = ReLU()(tensor)
        x = sep_bn(x, filters=728, kernel_size=3)
        x = ReLU()(x)
        x = sep_bn(x, filters=728, kernel_size=3)
        x = ReLU()(x)
        x = sep_bn(x, filters=728, kernel_size=3)

        tensor = Add()([tensor, x])

    return tensor

# %% [markdown]
# Exit Flow

# %%
def exit_flow(tensor):
    x = ReLU()(tensor)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=1024, kernel_size=3)
    x = MaxPool2D(3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=1024, kernel_size=1, strides=2)

    x = Add()([tensor, x])
    x = sep_bn(x, filters=1536, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=2048, kernel_size=3)
    x = ReLU()(x)
    x = GlobalAvgPool2D()(x)
    x = Dense(units=classes, activation='softmax')(x)

    return x

# %% [markdown]
# The Model Code

# %%
input = Input(shape=[299, 299, 3])
input=rescale(input)

x = entry_flow(input)
x = middle_flow(x)
output = exit_flow(x)

from tensorflow.keras import Model
model = Model(input, output)

# %% [markdown]
# # Defining Callbacks
#
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %%
import numpy as np
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Callback to reduce the learning rate when validation loss plateaus
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=np.sqrt(0.1),  # Factor to reduce learning rate
    patience=5,
    verbose=1
)

# Callback to stop training when validation loss doesn't improve
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,  # Number of epochs to wait before stopping
    verbose=1,
    restore_best_weights=True
)

# %% [markdown]
# Defining the Optimizer

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)

# %%
model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=2,
    epochs=epochs,
    class_weight = class_weights,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/100
#
# 172/172 - 145s - loss: 0.0243 - accuracy: 0.9910 - val_loss: 0.0573 - val_accuracy: 0.9805 - lr: 3.1623e-04 - 145s/epoch - 843ms/step
# Epoch 22/100
# 172/172 - 145s - loss: 0.0229 - accuracy: 0.9909 - val_loss: 0.0514 - val_accuracy: 0.9809 - lr: 3.1623e-04 - 145s/epoch - 843ms/step
# Epoch 23/100
# 172/172 - 145s - loss: 0.0224 - accuracy: 0.9907 - val_loss: 0.0635 - val_accuracy: 0.9825 - lr: 3.1623e-04 - 145s/epoch - 843ms/step
# Epoch 24/100
# 172/172 - 146s - loss: 0.0214 - accuracy: 0.9926 - val_loss: 0.0609 - val_accuracy: 0.9809 - lr: 3.1623e-04 - 146s/epoch - 846ms/step
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 172/172 - 145s - loss: 0.0219 - accuracy: 0.9906 - val_loss: 0.0564 - val_accuracy: 0.9815 - lr: 3.1623e-04 - 145s/epoch - 845ms/step
# Epoch 26/100
# 172/172 - 145s - loss: 0.0163 - accuracy: 0.9931 - val_loss: 0.0537 - val_accuracy: 0.9831 - lr: 1.0000e-04 - 145s/epoch - 844ms/step
# Epoch 27/100
# 172/172 - 145s - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0613 - val_accuracy: 0.9844 - lr: 1.0000e-04 - 145s/epoch - 843ms/step
# Epoch 28/100
# 172/172 - 145s - loss: 0.0119 - accuracy: 0.9953 - val_loss: 0.0654 - val_accuracy: 0.9841 - lr: 1.0000e-04 - 145s/epoch - 843ms/step
# Epoch 29/100
# 172/172 - 145s - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0662 - val_accuracy: 0.9847 - lr: 1.0000e-04 - 145s/epoch - 843ms/step
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# Restoring model weights from the end of the best epoch: 20.
# 172/172 - 145s - loss: 0.0118 - accuracy: 0.9955 - val_loss: 0.0756 - val_accuracy: 0.9825 - lr: 1.0000e-04 - 145s/epoch - 844ms/step
# Epoch 30: early stopping

# %%
scores = model.evaluate(test_ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-7029987b6c89> in <cell line: 1>()
# ----> 1 scores = model.evaluate(test_ds)
#
# NameError: name 'model' is not defined

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Healthy Leaf
# 2/2 [==============================] - 2s 18ms/step
# predicted label: Healthy Leaf

# %% [markdown]
# Plotting training and validation accuracy, loss and learning rate

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np



# Get true and predicted labels
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model.predict(images)  # Get model predictions
    y_pred.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes

# Confusion Matrix with class names
cf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf_matrix, annot=True, cmap="Blues", fmt="g", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 1s 767ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step

# %% [markdown]
# Classificaiton Report with Precision, recall and f1 score

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.99      0.97      0.98        72
#       Black spot       0.96      0.91      0.94       182
#  European Canker       1.00      1.00      1.00       223
#    Healthy Fruit       0.99      0.98      0.99       214
#     Healthy Leaf       0.98      0.99      0.98       258
# Leaf spot (scab)       1.00      0.99      0.99       338
#    Mosaic virus        0.94      0.99      0.97       275
#
#         accuracy                           0.98      1562
#        macro avg       0.98      0.98      0.98      1562
#     weighted avg       0.98      0.98      0.98      1562

# %% [markdown]
# ROC - AUC

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true = []
y_pred_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model.predict(images)  # Get model predictions (probabilities)
    y_pred_probs.extend(predictions)  # Collect predicted probabilities

# Convert to NumPy arrays
y_true = np.array(y_true)  # Ensure true labels are arrays
y_pred_probs = np.array(y_pred_probs)  # Ensure predicted probabilities are arrays

# Binarize the true labels to get a one-hot encoded representation
y_true_bin = label_binarize(y_true, classes=list(range(20)))

# Initialize ROC and AUC data
fpr = dict()  # False positive rates
tpr = dict()  # True positive rates
roc_auc = dict()  # AUC for each class

# Compute ROC and AUC for each class
for i in range(classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])  # ROC data for each class
    roc_auc[i] = auc(fpr[i], tpr[i])  # AUC for each class

# Compute macro-average AUC
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(classes)]))
mean_tpr = np.zeros_like(all_fpr)

# Compute mean true positive rates
for i in range(classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= classes  # Normalize by the number of classes
macro_auc = auc(all_fpr, mean_tpr)  # Macro-average AUC

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')  # Label with class names and AUC

# Plot the macro-average ROC curve
plt.plot(all_fpr, mean_tpr, color='k', linestyle='--', label=f'Macro-average ROC (AUC = {macro_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2/2 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 117ms/step

# %% [markdown]
# **Transfer Learning**

# %%
from keras.layers import Input

# this could also be the output a different Keras model or layer
input= Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
input = rescale(input)

# %%
# Load the xception pre-trained model without the top layer (fully connected layers)
xception = Xception(input_tensor=input, weights='imagenet', include_top=False)

# %%
# Freeze the layers of xception
for layer in xception.layers:
  layer.trainable =False

# %%
x = GlobalAveragePooling2D()(xception.output)
prediction = Dense(classes, activation ='softmax')(x)
#create a model object
model_tl =Model(inputs =xception.input, outputs =prediction)
#View the structure of the model
model_tl.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  sequential_1 (Sequential)   (None, 299, 299, 3)          0         ['input_2[0][0]']
#
#  block1_conv1 (Conv2D)       (None, 149, 149, 32)         864       ['sequential_1[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 149, 149, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 149, 149, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 147, 147, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 147, 147, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 147, 147, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 147, 147, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 147, 147, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 147, 147, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_4 (Conv2D)           (None, 74, 74, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_4 (Bat  (None, 74, 74, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_12 (Add)                (None, 74, 74, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 74, 74, 128)          0         ['add_12[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 74, 74, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 74, 74, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 74, 74, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 256)          32768     ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_5 (Bat  (None, 37, 37, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  add_13 (Add)                (None, 37, 37, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 37, 37, 256)          0         ['add_13[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 37, 37, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 37, 37, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 37, 37, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_6 (Conv2D)           (None, 19, 19, 728)          186368    ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 19, 19, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_6 (Bat  (None, 19, 19, 728)          2912      ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_14 (Add)                (None, 19, 19, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_14[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_15 (Add)                (None, 19, 19, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_14[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_15[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_16 (Add)                (None, 19, 19, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_15[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_16[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_17 (Add)                (None, 19, 19, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_16[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_17[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_18 (Add)                (None, 19, 19, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_17[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_18[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_19 (Add)                (None, 19, 19, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_18[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_19[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_20 (Add)                (None, 19, 19, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_19[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_20[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_21 (Add)                (None, 19, 19, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_20[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_21[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_22 (Add)                (None, 19, 19, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_21[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_22[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 19, 19, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 19, 19, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 1024)         745472    ['add_22[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 10, 10, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_7 (Bat  (None, 10, 10, 1024)         4096      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_23 (Add)                (None, 10, 10, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 10, 10, 1536)         1582080   ['add_23[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 10, 10, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 10, 10, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 10, 10, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 10, 10, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 10, 10, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 7)                    14343     ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 20875823 (79.63 MB)
# Trainable params: 14343 (56.03 KB)
# Non-trainable params: 20861480 (79.58 MB)
# __________________________________________________________________________________________________

# %%
#Define Callback
import numpy as np
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Callback to reduce the learning rate when validation loss plateaus
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=np.sqrt(0.1),  # Factor to reduce learning rate
    patience=5,
    verbose=1
)

# Callback to stop training when validation loss doesn't improve
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,  # Number of epochs to wait before stopping
    verbose=1,
    restore_best_weights=True
)

# %%
#Define the optimizer
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### Compiling the Model
# We use `adam` Optimizer, `SparseCategoricalCrossentropy` for losses, `accuracy` as a metric

# %%
model_tl.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model_tl.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=2,
    epochs=epochs,
    class_weight = class_weights,
    callbacks=[reduce_lr, early_stopping]
)
# Out:
# Epoch 1/100
# 172/172 - 96s - loss: 0.9585 - accuracy: 0.6203 - val_loss: 0.6359 - val_accuracy: 0.7873 - lr: 0.0010 - 96s/epoch - 557ms/step
# Epoch 2/100
# 172/172 - 32s - loss: 0.5823 - accuracy: 0.7880 - val_loss: 0.5305 - val_accuracy: 0.8205 - lr: 0.0010 - 32s/epoch - 186ms/step
# Epoch 3/100
# 172/172 - 32s - loss: 0.4803 - accuracy: 0.8323 - val_loss: 0.4417 - val_accuracy: 0.8511 - lr: 0.0010 - 32s/epoch - 186ms/step
# Epoch 4/100
# 172/172 - 32s - loss: 0.4205 - accuracy: 0.8563 - val_loss: 0.4333 - val_accuracy: 0.8466 - lr: 0.0010 - 32s/epoch - 186ms/step
# Epoch 5/100
# 172/172 - 32s - loss: 0.3786 - accuracy: 0.8699 - val_loss: 0.3802 - val_accuracy: 0.8705 - lr: 0.0010 - 32s/epoch - 186ms/step
# Epoch
# Epoch 68/100
# 172/172 - 32s - loss: 0.0770 - accuracy: 0.9799 - val_loss: 0.0957 - val_accuracy: 0.9716 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 69/100
# 172/172 - 32s - loss: 0.0769 - accuracy: 0.9797 - val_loss: 0.0948 - val_accuracy: 0.9719 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 70/100
# 172/172 - 32s - loss: 0.0767 - accuracy: 0.9802 - val_loss: 0.0956 - val_accuracy: 0.9719 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 71/100
# 172/172 - 32s - loss: 0.0766 - accuracy: 0.9797 - val_loss: 0.0929 - val_accuracy: 0.9729 - lr: 1.0000e-04 - 32s/epoch - 186ms/step
# Epoch 72/100
# 172/172 - 32s - loss: 0.0765 - accuracy: 0.9803 - val_loss: 0.0954 - val_accuracy: 0.9719 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 73/100
# 172/172 - 32s - loss: 0.0763 - accuracy: 0.9794 - val_loss: 0.0940 - val_accuracy: 0.9729 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 74/100
# 172/172 - 32s - loss: 0.0761 - accuracy: 0.9801 - val_loss: 0.0964 - val_accuracy: 0.9713 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 75/100
# 172/172 - 32s - loss: 0.0761 - accuracy: 0.9798 - val_loss: 0.0934 - val_accuracy: 0.9735 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 76/100
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 172/172 - 32s - loss: 0.0761 - accuracy: 0.9807 - val_loss: 0.0942 - val_accuracy: 0.9726 - lr: 1.0000e-04 - 32s/epoch - 185ms/step
# Epoch 77/100
# 172/172 - 32s - loss: 0.0755 - accuracy: 0.9801 - val_loss: 0.0936 - val_accuracy: 0.9723 - lr: 3.1623e-05 - 32s/epoch - 185ms/step
# Epoch 78/100
# 172/172 - 32s - loss: 0.0755 - accuracy: 0.9805 - val_loss: 0.0937 - val_accuracy: 0.9723 - lr: 3.1623e-05 - 32s/epoch - 185ms/step
# Epoch 79/100
# 172/172 - 32s - loss: 0.0755 - accuracy: 0.9802 - val_loss: 0.0935 - val_accuracy: 0.9723 - lr: 3.1623e-05 - 32s/epoch - 185ms/step
# Epoch 80/100
# 172/172 - 32s - loss: 0.0754 - accuracy: 0.9801 - val_loss: 0.0931 - val_accuracy: 0.9732 - lr: 3.1623e-05 - 32s/epoch - 185ms/step
# Epoch 81/100
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# Restoring model weights from the end of the best epoch: 71.
# 172/172 - 32s - loss: 0.0755 - accuracy: 0.9807 - val_loss: 0.0935 - val_accuracy: 0.9719 - lr: 3.1623e-05 - 32s/epoch - 186ms/step
# Epoch 81: early stopping

# %% [markdown]
# Evaluate the test_ds

# %%
scores = model_tl.evaluate(test_ds)
# Out:
# 25/25 [==============================] - 33s 144ms/step - loss: 0.0896 - accuracy: 0.9770

# %% [markdown]
# Evaluating the external test dataset

# %%
external_scores = model_tl.evaluate(external_test)
# Out:
# 12/12 [==============================] - 3s 140ms/step - loss: 2.2033 - accuracy: 0.5978

# %% [markdown]
# ### Run prediction on a sample image from the test_ds

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model_tl.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Mosaic virus
# 2/2 [==============================] - 1s 78ms/step
# predicted label: Mosaic virus

# %% [markdown]
# ##  Plotting the accuracy, loss and the epoch curves

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Learning Rate')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Confusion Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np



# Get true and predicted labels
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model_tl.predict(images)  # Get model predictions
    y_pred.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes

# Confusion Matrix with class names
cf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cf_matrix, annot=True, cmap="Blues", fmt="g", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 825ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 81ms/step

# %%
from sklearn.metrics import classification_report

report = classification_report(y_true, y_pred, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.99      0.99      0.99        72
#       Black spot       0.97      0.91      0.94       182
#  European Canker       1.00      1.00      1.00       223
#    Healthy Fruit       1.00      0.99      0.99       214
#     Healthy Leaf       0.97      0.99      0.98       258
# Leaf spot (scab)       0.99      0.97      0.98       338
#    Mosaic virus        0.94      0.99      0.97       275
#
#         accuracy                           0.98      1562
#        macro avg       0.98      0.98      0.98      1562
#     weighted avg       0.98      0.98      0.98      1562

# %% [markdown]
# ROC AUC

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

y_true = []
y_pred_probs = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())  # Collect true labels
    predictions = model_tl.predict(images)  # Get model predictions (probabilities)
    y_pred_probs.extend(predictions)  # Collect predicted probabilities

# Convert to NumPy arrays
y_true = np.array(y_true)  # Ensure true labels are arrays
y_pred_probs = np.array(y_pred_probs)  # Ensure predicted probabilities are arrays

# Binarize the true labels to get a one-hot encoded representation
y_true_bin = label_binarize(y_true, classes=list(range(20)))

# Initialize ROC and AUC data
fpr = dict()  # False positive rates
tpr = dict()  # True positive rates
roc_auc = dict()  # AUC for each class

# Compute ROC and AUC for each class
for i in range(classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])  # ROC data for each class
    roc_auc[i] = auc(fpr[i], tpr[i])  # AUC for each class

# Compute macro-average AUC
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(classes)]))
mean_tpr = np.zeros_like(all_fpr)

# Compute mean true positive rates
for i in range(classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= classes  # Normalize by the number of classes
macro_auc = auc(all_fpr, mean_tpr)  # Macro-average AUC

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')  # Label with class names and AUC

# Plot the macro-average ROC curve
plt.plot(all_fpr, mean_tpr, color='k', linestyle='--', label=f'Macro-average ROC (AUC = {macro_auc:.2f})')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step

# %% [markdown]
# Classification Report on External Dataset

# %%
# Get true and predicted labels
y_true_external = []
y_pred_external = []

for images, labels in external_test:
    y_true_external.extend(labels.numpy())  # Collect true labels
    predictions = model_tl.predict(images)  # Get model predictions
    y_pred_external.extend(tf.argmax(predictions, axis=1).numpy())  # Get predicted classes




report = classification_report(y_true_external, y_pred_external, target_names=class_names, zero_division=1)
print("Classification Report:\n", report)
# Out:
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# Classification Report:
#                    precision    recall  f1-score   support
#
#        Black rot       0.82      0.21      0.34        42
#       Black spot       0.32      0.62      0.42       120
#  European Canker       0.89      1.00      0.94        72
#    Healthy Fruit       0.64      0.98      0.78        90
#     Healthy Leaf       0.67      0.03      0.06       126
# Leaf spot (scab)       0.40      0.15      0.22        54
#    Mosaic virus        0.74      0.81      0.77       222
#
#         accuracy                           0.60       726
#        macro avg       0.64      0.54      0.50       726
#     weighted avg       0.64      0.60      0.54       726

# %% [markdown]
# ### Write a function for inference for the Transfer Learning model

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %% [markdown]
# **Now run inference on few sample images from the test model**

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model_tl, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Now run inference on few sample images from the external model

# %%
plt.figure(figsize=(15, 15))
for images, labels in external_test.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))

        predicted_class, confidence = predict(model_tl, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Save the Model

# %%
import os

# Define the base path for saving the model
base_path = "/content/drive/MyDrive/Classroom/Dissertation/models/"

# Ensure the base path exists
os.makedirs(base_path, exist_ok=True)

# Find the current highest model version (ensuring only numeric entries are considered)
numeric_dirs = [int(i) for i in os.listdir(base_path) if i.isdigit()]

# Determine the next model version
model_version = max(numeric_dirs + [0]) + 1

# Create the full path for saving the model, including the .h5 extension
model_path = os.path.join(base_path, f"{model_version}.h5")

# Save the model in HDF5 format
model_tl.save(model_path)
